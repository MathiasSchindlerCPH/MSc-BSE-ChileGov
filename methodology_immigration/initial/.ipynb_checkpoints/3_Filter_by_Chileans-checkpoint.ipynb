# %% [markdown]
# # Geotagging All Tweets  without Geolocation From Relevant Authors
# ***

# %% [markdown]
# **Project**: Master Thesis for MSc in Data Science for Decision Making
#
# **Institution**: Barcelona School of Economics, Class of 2022
#
# **Students**: Andrés Couble, Kalliope Stasssinos, Mathias Schindler
#
# **Notebook Author**: Mathias Schindler
#
# **Submission Date**: June 26, 2022

# %% [markdown]
# ![Screenshot%202022-05-21%20at%2018.16.14.png](attachment:Screenshot%202022-05-21%20at%2018.16.14.png)

# %% [markdown]
# **NB**
# <br>
# This script is set up such that all manual input can be done in the subsection `preamble` and the script will run autonomously. In the end it will save a `.csv`-file that is restricted to Chilean Twitter users defined by the criteria in this notebook.

# %% [markdown]
# **Criteria**
# <br>
# For observations to 'survive' this notebook, the features `author.description` or `author.location` should contain *at least* 1 of the folllowing textual characteristics:
# * Contain a Chilean emoji flag 🇨🇱
# * Contain the phrase 'chile' or a derivation thereof (e.g. 'chileno', 'chilena', etc.)
# * Contain an unambiguous Chilean city either as an $n$-gram or a unigram
#
# <br>
# By "unambiguous" we mean a city name which is not also a city name in another country than Chile (so e.g. *not* 'Florida', 'Cartagena', 'San Carlos', 'Los Lagos', etc.).

# %% [markdown]
# **Execution Time**
# <br>
# MacBook Pro (2020-model) with a 2 GHz Quad-Core Intel Core i5 and 16 GB RAM runs this notebook in 1 hour, 16 min and 57 seconds. (See also the very last code cell which prints total execution time of notebook.)

# %% [markdown]
# ### Preamble

# %%
# clear all
# %reset -f
print(dir())
# Out:
# ['In', 'Out', '__builtin__', '__builtins__', '__name__', '_dh', '_ih', '_oh', 'exit', 'get_ipython', 'quit']

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
import random
import unidecode
from IPython.display import clear_output
import emoji
import textwrap
from wordcloud import WordCloud
from nltk.corpus import stopwords

from datetime import datetime

# %%
from MyPreprLib.myprepr import myprepr as custom
print(dir(custom))

# # Reload if changes
# import sys, importlib
# importlib.reload(sys.modules['MyPreprLib.myprepr.myprepr'])

# # Print arguments for functions
# print(custom.make_other_country_df.__code__.co_varnames)
# print(custom.city_dict_df.__code__.co_varnames)
# Out:
# ['WordCloud', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'city_dict_df', 'cleanTweets', 'dict_regex_city', 'emoji', 'fix_na_loc_bio', 'make_other_country_df', 'np', 'pd', 're', 'regex_chile', 'stopwords', 'textwrap', 'tweets_preproz', 'unidecode', 'wordcloud_preproz']

# %%
notebook_start = datetime.now() #Start timer for entire notebook

# %%
# Setting: Show all columns in pd.DataFrame
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
#pd.options.display.max_colwidth = 200

# Resets
#pd.reset_option('display.max_colwidth')
#pd.reset_option('display.max_rows')

# %%
# Set path + separator
path = "/Users/mathiasschindler/Library/Mobile Documents/com~apple~CloudDocs/BSE/_T3--Thesis/data_in"
out_path = '/Users/mathiasschindler/Library/Mobile Documents/com~apple~CloudDocs/BSE/_T3--Thesis/data_out'
sep = "/"

# %%
# Set filename
twarc_data_test = "immigration_tweets_v2.csv"
twarc_data = "all_tweets_cleaned.csv"

# %%
# Set name for exportet csv
date_file = str(datetime.now().strftime('%y-%m-%d'))
out_filename = date_file + '-' + 'all_tweets_cleaned_filter_chileans.csv'
out_file = out_path + sep + out_filename
print(out_file)
# Out:
# /Users/mathiasschindler/Library/Mobile Documents/com~apple~CloudDocs/BSE/_T3--Thesis/data_out/22-06-03-all_tweets_cleaned_filter_chileans.csv

# %% [markdown]
# # 1. Construct Author Location Features

# %% [markdown]
# ## 1.0 Load Data, Set Lists

# %% [markdown]
# ### 1.0.1 `twarc`-Data

# %%
print(twarc_data)
# Out:
# all_tweets_cleaned.csv

# %%
# Load twarc data
df = pd.read_csv(path + sep + twarc_data, index_col = 0)
correct_cols = pd.read_csv(path + sep + twarc_data_test, index_col = 0)

# Ensure columns are in 'raw' twarc-format (integer-ordering of variables is essential for this script)
#df = df[df.columns.drop(list(df.filter(regex = 'Unnamed:')))]
df = df[correct_cols.columns.to_list()]
# Out:
# /var/folders/38/pqdkmnzn27z4y7tybr0ccrnc0000gn/T/ipykernel_65131/695686629.py:2: DtypeWarning: Columns (22,23,25,33,35,36,37,43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path + sep + twarc_data, index_col = 0)
# /var/folders/38/pqdkmnzn27z4y7tybr0ccrnc0000gn/T/ipykernel_65131/695686629.py:3: DtypeWarning: Columns (20,21,22,24,32,34,35,36,42,57,59,60,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   correct_cols = pd.read_csv(path + sep + twarc_data_test, index_col = 0)

# %%
df.shape
# Out:
# (897783, 74)

# %%
# Make list to run loop over 2 columns in df
cols_list_loop = ['author.location', 'author.description']

# %% [markdown]
# ### 1.0.2 Wikipedia Tables

# %% [markdown]
# 1) List of countries in the world in Spanish from Wikipedia (https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses):

# %%
# Set URL
paises_url = "https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses"

# Read html
paises_wiki = pd.read_html(paises_url, header = 0)

# Select table and columns
paises_wiki = paises_wiki[0]
paises_wiki = paises_wiki['Nombre común']

# Preprocess list with custom function "tweets_preproz()"
paises_wiki = pd.Series(paises_wiki)
paises_wiki = custom.tweets_preproz(df = paises_wiki, drop_na = False, drop_dup = True)

# Convert to list
pais_l = paises_wiki.to_list()

# Remove spacing some list elements
pais_l = ["".join(s.split()) for s in pais_l]
pais_l = [s.replace("/", "") for s in pais_l]
pais_l = [s.replace("-", "_") for s in pais_l]

# %% [markdown]
# 2) List of Chilean cities from Wikipedia (https://en.wikipedia.org/wiki/List_of_cities_in_Chile):

# %%
# Set URL
cities_url = "https://en.wikipedia.org/wiki/List_of_cities_in_Chile"

# Read html
ch_cit = pd.read_html(cities_url, header = 0)

# Select table and columns
ch_cit = ch_cit[1]
ch_cit = ch_cit[['Region', 'City']] 

# Preprocessing 1: Lowercase
ch_cit = ch_cit.applymap(lambda s: s.lower() if type(s) == str else s) # lowercase

# Preprocessing 2: Remove "[note 2]/[note 3]"
ch_cit['Region'] = ch_cit['Region'].str.replace(r'\[note \d\]', '', regex=True)
ch_cit['City'] = ch_cit['City'].str.replace(r'\[note \d\]', '', regex=True)

# Preprocessing 3: Unidecode (remove accents and Spanish ñ)
ch_cit['Region'] = ch_cit['Region'].apply(unidecode.unidecode)
ch_cit['City'] = ch_cit['City'].apply(unidecode.unidecode)

# Concatenate both columns into one pandas series
ch_cit_con = pd.concat([ch_cit['Region'], ch_cit['City']])

# Drop duplicates
ch_cit_con = ch_cit_con.drop_duplicates()

# Convert to list
ch_reg_cit_uniq = ch_cit_con.to_list()

# %% [markdown]
# ## 1.1 Emoji: Chilean Flag

# %%
# Test
print('Demojized Chilean flag emoji is \n', emoji.demojize('🇨🇱'))
# Out:
# Demojized Chilean flag emoji is
#  :Chile:

# %%
start = datetime.now() #Start timer

for col in cols_list_loop:
    
# 1. Preprocess 
    # Demojize: Requires string and no NaN
    df[col] = df[col].astype("string").fillna("0")
    
    # Demojize: Apply function
    df[col] = df[col].apply(emoji.demojize)
    
#2. Make Boolean column if containing Chilean flag emoji
    if col == 'author.location':
        
        # Making new columns with custom function, regex_chile()
        new_col = 'loc_chile_emoji'
        loc_emoji_chile_flag = custom.regex_chile(df = df, col = col, 
                                                  colname = new_col)
        df = df.drop(new_col, axis = 1)
        
    elif col == 'author.description':
        
        # Making new columns with custom function, regex_chile()
        new_col = 'bio_chile_emoji'
        bio_emoji_chile_flag = custom.regex_chile(df = df, col = col, 
                                                  colname = new_col)
        df = df.drop(new_col, axis = 1)
        
    else:
        pass
    
print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Runtime: 0:00:25.246454

# %% [markdown]
# ## 1.2 RegEx: Containing `'chile'`

# %% [markdown]
# Regular expression `'chile'` also captures 'chileno', 'chilena', etc.

# %%
start = datetime.now() #Start timer

for col in cols_list_loop:
    locs = df[col]
    
## 1.2 Data Preparation
    locs_pd = custom.tweets_preproz(df = locs, 
                             drop_na = True, 
                             drop_dup = True)

## 1.3 Filter with Regex
    # Find all author locations containing 'chile'
    locs_pd_dict = locs_pd[locs_pd.str.match(r'((.*?)chile(.*?))') == True]

# 2. Merge with Dataset
    # Convert dict to pd.DataFrame
    locs_df_dict = locs_pd_dict.to_frame()

## 2.2 Preprocessing given column
    df_preproz = df.copy()
    df_preproz[col] = custom.tweets_preproz(df = df_preproz[col], 
                                            drop_na = False, 
                                            drop_dup = False)
    
## 2.3 Implement Merging
    # Pre-Merge: Make df with boolean column all True
    df_chile_regex_tmp = df_preproz.merge(locs_df_dict, 
                                      on = col,
                                      validate = 'm:1')
    
    # Add boolean indiciator
    df_chile_regex_tmp['contains_chile'] = True

    # Keep only 2 cols
    df_chile_regex_tmp = df_chile_regex_tmp[['id', 'contains_chile']]

    # Print resulting df
    df_chile_regex = df_preproz.merge(df_chile_regex_tmp, 
                                      on = 'id',
                                      how = 'left',
                                      validate = '1:1',
                                      indicator = True)
    
    print('Proportion matched:', "{:.2f}".format(len(df_chile_regex_tmp)/len(df)*100),'%')

    # Rearrange columns
    new_col_order = ['id', 'conversation_id', 'author_id', 'author.description', 'author.location', 'contains_chile']
    df_chile_regex = df_chile_regex[new_col_order]
    
    if col == 'author.location':
        loc_regex_chile = df_chile_regex.rename(columns = {'contains_chile':'loc_contains_chile'})
        
    elif col == 'author.description':
        bio_regex_chile = df_chile_regex.rename(columns = {'contains_chile':'bio_contains_chile'})
        
    else:
        pass
    
print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Proportion matched: 43.14 %
# Proportion matched: 25.79 %
# Runtime: 0:00:49.690039

# %% [markdown]
# ## 1.3 RegEx: Other Countries Than Chile

# %%
# For custom function "make_other_country_df()":
old_cols = ['any_count_not_chile', 'chile', 'afganistan', 'albania', 'alemania', 'andorra', 'angola', 
            'antiguaybarbuda', 'arabiasauditaarabiasaudi', 'argelia', 'argentina', 'armenia', 'australia', 
            'austria', 'azerbaiyan', 'bahamas', 'banglades', 'barbados', 'barein', 'belgica', 'belice', 'benin', 
            'bielorrusia', 'birmaniamyanmar', 'bolivia', 'botsuana', 'brasil', 'brunei', 'bulgaria', 'burkinafaso', 
            'burundi', 'butan', 'caboverde', 'camboya', 'camerun', 'canada', 'catar', 'republicacentroafricana', 
            'chad', 'republicachecachequia', 'china', 'chipre', 'colombia', 'comoras', 'republicadelcongo', 
            'republicademocraticadelcongo', 'coreadelnorte', 'coreadelsur', 'costademarfil', 'costarica', 
            'croacia', 'cuba', 'dinamarca', 'dominica', 'republicadominicana', 'ecuador', 'egipto', 'elsalvador', 
            'emiratosarabesunidos', 'eritrea', 'eslovaquia', 'eslovenia', 'espana', 'estadosunidos', 'estonia', 
            'etiopia', 'filipinas', 'finlandia', 'fiyi', 'francia', 'gabon', 'gambia', 'georgia', 'ghana', 
            'granada', 'grecia', 'guatemala', 'guinea', 'guineaecuatorial', 'guyana', 'haiti', 'honduras', 
            'hungria', 'india', 'indonesia', 'irak', 'iran', 'irlanda', 'islandia', 'israel', 'italia', 'jamaica', 
            'japon', 'jordania', 'kazajistan', 'kenia', 'kirguistan', 'kiribati', 'kuwait', 'laos', 'lesoto', 
            'letonia', 'libano', 'liberia', 'libia', 'liechtenstein', 'lituania', 'luxemburgo', 'macedoniadelnorte', 
            'madagascar', 'malasia', 'malaui', 'maldivas', 'malimali', 'malta', 'marruecos', 'islasmarshall', 
            'mauricio', 'mauritania', 'mexico', 'micronesia', 'moldavia', 'monaco', 'mongolia', 'montenegro', 
            'mozambique', 'namibia', 'nauru', 'nepal', 'nicaragua', 'niger', 'nigeria', 'noruega', 
            'nuevazelandanuevazelandia', 'oman', 'paisesbajos', 'pakistan', 'palaos', 'palestina', 'panama', 
            'papuanuevaguinea', 'paraguay', 'peru', 'polonia', 'portugal', 'reinounido', 'ruanda', 'rumaniarumania', 
            'rusia', 'islassalomon', 'samoa', 'sancristobalynieves', 'sanmarino', 'sanvicenteylasgranadinas', 
            'santalucia', 'santotomeyprincipe', 'senegal', 'serbia', 'seychelles', 'sierraleona', 'singapur', 
            'siria', 'somalia', 'srilanka', 'suazilandiaesuatini', 'sudafrica', 'sudan', 'sudandelsur', 'suecia', 
            'suiza', 'surinam', 'tailandia', 'tanzania', 'tayikistan', 'timororiental', 'togo', 'tonga', 
            'trinidadytobago', 'tunez', 'turkmenistan', 'turquia', 'tuvalu', 'ucrania', 'uganda', 'uruguay', 
            'uzbekistan', 'vanuatu', 'ciudaddelvaticano', 'venezuela', 'vietnam', 'yemen', 'yibuti', 'zambia', 
            'zimbabue']

# %%
start = datetime.now() #Start timer

for col in cols_list_loop:
## 1.1 Data Preparation
    locs = df[col]
    locs_pd = custom.tweets_preproz(df = locs, drop_na = False, drop_dup = False)
    
## 1.2 Filter with Regex
    ### 1.2.1 Identify Countries in Author Locs/bio using RegEx
    df_l = []
    
    for pais in pais_l:
        print("regex'ing:", col, ":", pais)
        # Make regular expression
        regex = '(.*?)' + pais + '(.*?)'

        # RegEx: Containing other country than Chile
        globals()['df_%s' % pais] = locs_pd[locs_pd.str.match(regex) == True]

        # Convert to df
        globals()['df_%s' % pais] = globals()['df_%s' % pais].to_frame()

        # Add boolean column
        globals()['df_%s' % pais][pais] = True

        # Remove other column
        globals()['df_%s' % pais] = globals()['df_%s' % pais].drop(col, axis = 1)
        
        # Give name to pd.DataFrame
        globals()['df_%s' % pais].name = str(pais)
        
        # Append to list
        df_l.append(globals()['df_%s' % pais])
        #df_l.remove("df_o'higgins")
        #df_l.remove("df_llay-llay")
    print("\n")
        
# 2. Merge with Dataset
## 2.1 Prepare df for Merge
    # Make copy
    df_preproz = df.copy()
    df_preproz[col] = custom.tweets_preproz(df = df_preproz[col], 
                                     drop_na = False, 
                                     drop_dup = False)
    
## 2.2 Implement Merging    
    # Loop over auxiliary dfs to merge with
    df_notchile_regex = df_preproz.copy()
    for l in df_l:
        print('merging:', col, ":", l.name)
        df_notchile_regex = df_notchile_regex.merge(l, how = 'left', left_index = True, right_index = True)
    print("\n")
        
# 3. Prepare each (of 2) df for export
    if col == 'author.location':
        loc_regex_othercountry = custom.make_other_country_df(old_cols = old_cols,
                                                              prefix = 'loc_', 
                                                              df_in = df_notchile_regex, 
                                                              bool_col_name = 'bool_any_count_not_chile', 
                                                              col_new_name = 'loc_any_other_country')
    elif col == 'author.description':
        bio_regex_othercountry = custom.make_other_country_df(old_cols = old_cols,
                                                              prefix = 'bio_', 
                                                              df_in = df_notchile_regex, 
                                                              bool_col_name = 'bool_any_count_not_chile', 
                                                              col_new_name = 'bio_any_other_country')
        
    else:
        pass
        
clear_output(); print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Runtime: 0:16:58.256200

# %% [markdown]
# ## 1.4 Dictionary Method: Chilean Cities

# %% [markdown]
# ### 1.4.1 Construct Dictionaries

# %%
## 2.1 – Dictionary A: List of Chilean Cities as $n$-Grams

# n-grams is same as output from previous cell
ch_cit_ngram = ch_reg_cit_uniq
print('List length n-grams:', len(ch_cit_ngram))

## 2.2 – Dictionary B: List of Chilean Cities as Unigrams

# Unigrams
ch_reg_cit_split = ' '.join(ch_reg_cit_uniq).split()
print('List length (after split):', len(ch_reg_cit_split))

#Remove duplicates
ch_reg_cit_split = list(dict.fromkeys(ch_reg_cit_split))

# Remove 'useless' words
ch_reg_cit_split.remove('los')
ch_reg_cit_split.remove('las')
ch_reg_cit_split.remove('el')
ch_reg_cit_split.remove('la')
ch_reg_cit_split.remove('lo')
ch_reg_cit_split.remove('de')
ch_reg_cit_split.remove('del')
ch_reg_cit_split.remove('san')
ch_reg_cit_split.remove('and')
ch_reg_cit_split.remove('region')

ch_cit_unigram = ch_reg_cit_split
print('\n List length Unigrams (no dups, no stopwords):', len(ch_cit_unigram))
# Out:
# List length n-grams: 243
# List length (after split): 352
#
#  List length Unigrams (no dups, no stopwords): 263

# %%
# Manually exclude ambiguous cities
n_grams_exclude = ['algarrobo', 'bulnes', 'cabildo', 'caldera', 'calle larga', 'cartagena', 
                   'casablanca', 'castro', 'colina', 'concepcion', 'constitucion', 'coronel',
                   'diego de almagro', 'el bosque', 'el melon', 'el monte', 'el salvador', 
                   'estacion central', 'freire', 'fresia', 'gorbea', 'graneros', 'hospital', 
                   'independencia', 'la calera', 'la cruz', 'la florida', 'la granja', 
                   'la islita', 'la laja', 'la reina', 'la serena', 'la union', 'labranza', 
                   'lampa', 'las cabras', 'las ventanas', 'lautaro', 'linares', 'lo espejo', 
                   'los alamos', 'los andes', 'los angeles', 'los lagos', 'los rios', 'lota', 
                   'magallanes', 'maria elena', 'mejillones', 'molina', 'mostazal', 
                   'nacimiento', 'nogales', 'osorno', 'padre hurtado', 'palmilla', 
                   'pedro aguirre cerda', 'penaflor', 'penco', 'peumo', 'providencia', 
                   'quintero', 'recoleta', 'rengo', 'rio bueno', 'rio negro', 'salamanca', 
                   'san antonio', 'san bernardo', 'san carlos', 'san clemente', 'san esteban', 
                   'san felipe', 'san fernando', 'san javier', 'san joaquin', 'san miguel', 
                   'san ramon', 'san rosendo', 'santa barbara', 'santa cruz', 'santa juana', 
                   'santa maria', 'santo domingo', 'teno', 'tome', 'victoria', 'vicuna', 'yungay']
unigrams_exclude = ['aguila', 'aguirre', 'agustin', 'alamos', 'alegre', 'alemana', 
                    'algarrobo', 'almagro', 'almonte', 'alto', 'amarilla', 'andes', 
                    'angeles', 'antonio', 'arenas', 'bajos', 'barbara', 'bernardo', 
                    'bosque', 'bueno', 'bulnes', 'cabildo', 'cabras', 'cabrero', 'caldera', 
                    'calle', 'carlos', 'cartagena', 'casablanca', 'casas', 'castro', 
                    'central', 'cerda', 'cerro', 'cisterna', 'clemente', 'colina', 
                    'concepcion', 'condes', 'constitucion', 'coronel', 'cruz', 'diego', 
                    'domingo', 'elena', 'espejo', 'estacion', 'esteban', 'felipe', 
                    'fernando', 'florida', 'freire', 'fresia', 'gorbea', 'granja', 
                    'hospicio', 'hospital', 'hurtado', 'imperial', 'independencia', 'isla', 
                    'islita', 'jahuel', 'javier', 'joaquin', 'jose', 'juana', 'labranza', 
                    'lagos', 'laja', 'lampa', 'larga', 'lautaro', 'linares', 'lota', 
                    'magallanes', 'mar', 'maria', 'mejillones', 'melon', 'metropolitan', 
                    'miguel', 'miranda', 'molina', 'monte', 'montt', 'mostazal', 
                    'nacimiento', 'natales', 'navia', 'negro', 'nogales', 'normal', 
                    'nueva', 'osorno', 'padre', 'palmilla', 'palqui', 'parral', 'patria', 
                    'paz', 'pedro', 'penaflor', 'penco', 'penuelas', 'peumo', 'pozo', 
                    'prado', 'providencia', 'puente', 'puerto', 'punta', 'quinta', 
                    'quintero', 'ramon', 'recoleta', 'reina', 'rengo', 'rinconada', 'rio', 
                    'rios', 'rosendo', 'salamanca', 'salvador', 'santa', 'santo', 'serena', 
                    'tabo', 'tagua', 'teno', 'tierra', 'tome', 'union', 'varas', 
                    'ventanas', 'vicente', 'victoria', 'vicuna', 'viejo', 'villa', 
                    'vina', 'yungay', 'zaldivar']

for city in n_grams_exclude:
    ch_cit_ngram.remove(city)
for city in unigrams_exclude:
    ch_cit_unigram.remove(city)
    
# Sort lists alphabetically
ch_cit_ngram.sort(); ch_cit_unigram.sort()
    
#Convert both (ngram + unigram) to dataframe
df_ch_cit_ngram = pd.DataFrame(ch_cit_ngram)
df_ch_cit_unigram = pd.DataFrame(ch_cit_unigram)

# %% [markdown]
# ### 1.4.2 Apply Dictionary Method as `for` Loop

# %%
start = datetime.now() #Start timer

for col in cols_list_loop:
# 3. Preprocessing 'author.location' column
    # Make copy
    df_preproz = df.copy()
  
    # Preprocessing custom function "tweets_preproz()"
    df_preproz[col] = custom.tweets_preproz(df = df_preproz[col], 
                                            drop_na = False, 
                                            drop_dup = False)


# 4. Identify Regular Expressions in Author Locs / bio

##########################################################################
## 4.1 Identify Dict A ($n$-Grams) in Dataset
    
    # List with underscores
    ch_cit_ngram_var = [s.replace(" ", "_") for s in ch_cit_ngram]
    ch_cit_ngram_var = [s.replace("-", "_") for s in ch_cit_ngram_var]

    # Make dict
    ch_cit_ngram_dict = {ch_cit_ngram[i]: ch_cit_ngram_var[i] for i in range(len(ch_cit_ngram))}

    # Copy
    df_preproz_A = df_preproz.copy()

    # Make regular expression with custom function "dict_regex_city()"
    dfA_l = []
    
    for key, val in ch_cit_ngram_dict.items():
        print("regex'ing n-grams", col, ":", val)
        regex = '(.*?)' + key + '(.*?)'
        globals()['dfA_%s' % val] = custom.dict_regex_city(df_out_prefix = 'dfA', 
                                                           df_in = df_preproz_A, 
                                                           col = col, 
                                                           regex = regex, 
                                                           city = val)
        dfA_l.append(globals()['dfA_%s' % val])
    print("\n")

    # Loop over auxiliary dfs to merge with
    df_chile_cit_ngran = df_preproz.copy()
    for l in dfA_l:
        print('merging n-grams:', col, ":", l.name)
        df_chile_cit_ngran = df_chile_cit_ngran.merge(l, how = 'left', left_index = True, right_index = True)
    print("\n")
    
    # Rearrange + select cols
    old_cols = df_chile_cit_ngran.iloc[:, 74:].columns.to_list()
        
    if col == 'author.location':
        loc_city_ngram = custom.city_dict_df(prefix = 'loc_', 
                                             old_cols = old_cols,
                                             df_in = df_chile_cit_ngran, 
                                             bool_col_name = 'bool_loc_any_ngram_city', 
                                             col_new_name = 'loc_any_ngram_city')
        
    elif col == 'author.description':
        bio_city_ngram = custom.city_dict_df(prefix = 'bio_', 
                                             old_cols = old_cols,
                                             df_in = df_chile_cit_ngran, 
                                             bool_col_name = 'bool_bio_any_ngram_city', 
                                             col_new_name = 'bio_any_ngram_city')
        
    else:
        pass

    
##########################################################################
## 4.2 Identify Dict B (Unigrams) in Dataset
    df_l = []
    
    for n in ch_cit_unigram:
        # Make regular expression with custom function "dict_regex_city()"
        print("regex'ing unigrams:", col, ":", n)
        regex = '(.*?)' + n + '(.*?)'
        globals()['df_%s' % n] = custom.dict_regex_city(df_out_prefix = 'df', 
                                                        df_in = df_preproz, 
                                                        col = col, 
                                                        regex = regex, 
                                                        city = n)
        df_l.append(globals()['df_%s' % n])
    print("\n")

    # Loop over auxiliary dfs to merge with
    df_chile_cit_unig = df_preproz.copy()
    for l in df_l:
        print('merging unigrams:', col, ":", l.name)
        df_chile_cit_unig = df_chile_cit_unig.merge(l, how = 'left', left_index = True, right_index = True)
    print("\n")
        
    # Rearrange + select cols
    old_cols = df_chile_cit_unig.iloc[:, 74:].columns.to_list()
    
    if col == 'author.location':
        loc_city_unigram = custom.city_dict_df(prefix = 'loc_',
                                               old_cols = old_cols,
                                               df_in = df_chile_cit_unig, 
                                               bool_col_name = 'bool_loc_any_unigram_city', 
                                               col_new_name = 'loc_any_unigram_city')
    
    elif col == 'author.description':
        bio_city_unigram = custom.city_dict_df(prefix = 'bio_', 
                                               old_cols = old_cols,
                                               df_in = df_chile_cit_unig, 
                                               bool_col_name = 'bool_bio_any_unigram_city', 
                                               col_new_name = 'bio_any_unigram_city')
        
    else:
        pass

clear_output(); print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Runtime: 0:22:58.910910

# %% [markdown]
# ### 1.5 Print Auxiliary Datasets

# %% [markdown]
# ### 1.5.1 Emoji: Chilean Flag

# %%
loc_emoji_chile_flag.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#                                   author.description          author.location  \
# 0                                                NaN                    Chile
# 1  Periodista, anti corrupción, anti hipocresía y...                        0
# 2  Periodista, anti corrupción, anti hipocresía y...                        0
# 3  Escribo en @noticiasrevista En Instagram como ...  Buenos Aires, Argentina
# 4  Escribo en @noticiasrevista En Instagram como ...  Buenos Aires, Argentina
#
#    loc_chile_emoji
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %%
bio_emoji_chile_flag.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#                                   author.description          author.location  \
# 0                                                  0                    Chile
# 1  Periodista, anti corrupción, anti hipocresía y...                        0
# 2  Periodista, anti corrupción, anti hipocresía y...                        0
# 3  Escribo en @noticiasrevista En Instagram como ...  Buenos Aires, Argentina
# 4  Escribo en @noticiasrevista En Instagram como ...  Buenos Aires, Argentina
#
#    bio_chile_emoji
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False

# %% [markdown]
# ### 1.5.2 RegEx: Containing `'Chile'`

# %%
loc_regex_chile.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#                                   author.description          author.location  \
# 0                                                  0                    chile
# 1  Periodista, anti corrupción, anti hipocresía y...                        0
# 2  Periodista, anti corrupción, anti hipocresía y...                        0
# 3  Escribo en @noticiasrevista En Instagram como ...  buenos aires, argentina
# 4  Escribo en @noticiasrevista En Instagram como ...  buenos aires, argentina
#
#   loc_contains_chile
# 0               True
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
bio_regex_chile.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#                                   author.description          author.location  \
# 0                                                  0                    Chile
# 1  periodista, anti corrupcion, anti hipocresia y...                        0
# 2  periodista, anti corrupcion, anti hipocresia y...                        0
# 3  escribo en @noticiasrevista en instagram como ...  Buenos Aires, Argentina
# 4  escribo en @noticiasrevista en instagram como ...  Buenos Aires, Argentina
#
#   bio_contains_chile
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# ### 1.5.3 RegEx: Other Countries Than Chile

# %%
loc_regex_othercountry.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#    loc_any_other_country loc_afganistan loc_albania loc_alemania loc_andorra  \
# 0                   True            NaN         NaN          NaN         NaN
# 1                  False            NaN         NaN          NaN         NaN
# 2                  False            NaN         NaN          NaN         NaN
# 3                   True            NaN         NaN          NaN         NaN
# 4                   True            NaN         NaN          NaN         NaN
#
#   loc_angola loc_antiguaybarbuda loc_arabiasauditaarabiasaudi loc_argelia  \
# 0        NaN                 NaN                          NaN         NaN
# 1        NaN                 NaN                          NaN         NaN
# 2        NaN                 NaN                          NaN         NaN
# 3        NaN                 NaN                          NaN         NaN
# 4        NaN                 NaN                          NaN         NaN
#
#   loc_argentina loc_armenia loc_australia loc_austria loc_azerbaiyan  \
# 0           NaN         NaN           NaN         NaN            NaN
# 1           NaN         NaN           NaN         NaN            NaN
# 2           NaN         NaN           NaN         NaN            NaN
# 3          True         NaN           NaN         NaN            NaN
# 4          True         NaN           NaN         NaN            NaN
#
#   loc_bahamas loc_banglades loc_barbados loc_barein loc_belgica loc_belice  \
# 0         NaN           NaN          NaN        NaN         NaN        NaN
# 1         NaN           NaN          NaN        NaN         NaN        NaN
# 2         NaN           NaN          NaN        NaN         NaN        NaN
# 3         NaN           NaN          NaN        NaN         NaN        NaN
# 4         NaN           NaN          NaN        NaN         NaN        NaN
#
#   loc_benin loc_bielorrusia loc_birmaniamyanmar loc_bolivia  \
# 0       NaN             NaN                 NaN         NaN
# 1       NaN             NaN                 NaN         NaN
# 2       NaN             NaN                 NaN         NaN
# 3       NaN             NaN                 NaN         NaN
# 4       NaN             NaN                 NaN         NaN
#
#   bosniayherzegovinabosnia_herzegovina loc_botsuana loc_brasil loc_brunei  \
# 0                                  NaN          NaN        NaN        NaN
# 1                                  NaN          NaN        NaN        NaN
# 2                                  NaN          NaN        NaN        NaN
# 3                                  NaN          NaN        NaN        NaN
# 4                                  NaN          NaN        NaN        NaN
#
#   loc_bulgaria loc_burkinafaso loc_burundi loc_butan loc_caboverde  \
# 0          NaN             NaN         NaN       NaN           NaN
# 1          NaN             NaN         NaN       NaN           NaN
# 2          NaN             NaN         NaN       NaN           NaN
# 3          NaN             NaN         NaN       NaN           NaN
# 4          NaN             NaN         NaN       NaN           NaN
#
#   loc_camboya loc_camerun loc_canada loc_catar loc_republicacentroafricana  \
# 0         NaN         NaN        NaN       NaN                         NaN
# 1         NaN         NaN        NaN       NaN                         NaN
# 2         NaN         NaN        NaN       NaN                         NaN
# 3         NaN         NaN        NaN       NaN                         NaN
# 4         NaN         NaN        NaN       NaN                         NaN
#
#   loc_chad loc_republicachecachequia loc_chile loc_china loc_chipre  \
# 0      NaN                       NaN      True       NaN        NaN
# 1      NaN                       NaN       NaN       NaN        NaN
# 2      NaN                       NaN       NaN       NaN        NaN
# 3      NaN                       NaN       NaN       NaN        NaN
# 4      NaN                       NaN       NaN       NaN        NaN
#
#   loc_colombia loc_comoras loc_republicadelcongo  \
# 0          NaN         NaN                   NaN
# 1          NaN         NaN                   NaN
# 2          NaN         NaN                   NaN
# 3          NaN         NaN                   NaN
# 4          NaN         NaN                   NaN
#
#   loc_republicademocraticadelcongo loc_coreadelnorte loc_coreadelsur  \
# 0                              NaN               NaN             NaN
# 1                              NaN               NaN             NaN
# 2                              NaN               NaN             NaN
# 3                              NaN               NaN             NaN
# 4                              NaN               NaN             NaN
#
#   loc_costademarfil loc_costarica loc_croacia loc_cuba loc_dinamarca  \
# 0               NaN           NaN         NaN      NaN           NaN
# 1               NaN           NaN         NaN      NaN           NaN
# 2               NaN           NaN         NaN      NaN           NaN
# 3               NaN           NaN         NaN      NaN           NaN
# 4               NaN           NaN         NaN      NaN           NaN
#
#   loc_dominica loc_republicadominicana loc_ecuador loc_egipto loc_elsalvador  \
# 0          NaN                     NaN         NaN        NaN            NaN
# 1          NaN                     NaN         NaN        NaN            NaN
# 2          NaN                     NaN         NaN        NaN            NaN
# 3          NaN                     NaN         NaN        NaN            NaN
# 4          NaN                     NaN         NaN        NaN            NaN
#
#   loc_emiratosarabesunidos loc_eritrea loc_eslovaquia loc_eslovenia  \
# 0                      NaN         NaN            NaN           NaN
# 1                      NaN         NaN            NaN           NaN
# 2                      NaN         NaN            NaN           NaN
# 3                      NaN         NaN            NaN           NaN
# 4                      NaN         NaN            NaN           NaN
#
#   loc_espana loc_estadosunidos loc_estonia loc_etiopia loc_filipinas  \
# 0        NaN               NaN         NaN         NaN           NaN
# 1        NaN               NaN         NaN         NaN           NaN
# 2        NaN               NaN         NaN         NaN           NaN
# 3        NaN               NaN         NaN         NaN           NaN
# 4        NaN               NaN         NaN         NaN           NaN
#
#   loc_finlandia loc_fiyi loc_francia loc_gabon loc_gambia loc_georgia  \
# 0           NaN      NaN         NaN       NaN        NaN         NaN
# 1           NaN      NaN         NaN       NaN        NaN         NaN
# 2           NaN      NaN         NaN       NaN        NaN         NaN
# 3           NaN      NaN         NaN       NaN        NaN         NaN
# 4           NaN      NaN         NaN       NaN        NaN         NaN
#
#   loc_ghana loc_granada loc_grecia loc_guatemala loc_guinea guinea_bisau  \
# 0       NaN         NaN        NaN           NaN        NaN          NaN
# 1       NaN         NaN        NaN           NaN        NaN          NaN
# 2       NaN         NaN        NaN           NaN        NaN          NaN
# 3       NaN         NaN        NaN           NaN        NaN          NaN
# 4       NaN         NaN        NaN           NaN        NaN          NaN
#
#   loc_guineaecuatorial loc_guyana loc_haiti loc_honduras loc_hungria  \
# 0                  NaN        NaN       NaN          NaN         NaN
# 1                  NaN        NaN       NaN          NaN         NaN
# 2                  NaN        NaN       NaN          NaN         NaN
# 3                  NaN        NaN       NaN          NaN         NaN
# 4                  NaN        NaN       NaN          NaN         NaN
#
#   loc_india loc_indonesia loc_irak loc_iran loc_irlanda loc_islandia  \
# 0       NaN           NaN      NaN      NaN         NaN          NaN
# 1       NaN           NaN      NaN      NaN         NaN          NaN
# 2       NaN           NaN      NaN      NaN         NaN          NaN
# 3       NaN           NaN      NaN      NaN         NaN          NaN
# 4       NaN           NaN      NaN      NaN         NaN          NaN
#
#   loc_israel loc_italia loc_jamaica loc_japon loc_jordania loc_kazajistan  \
# 0        NaN        NaN         NaN       NaN          NaN            NaN
# 1        NaN        NaN         NaN       NaN          NaN            NaN
# 2        NaN        NaN         NaN       NaN          NaN            NaN
# 3        NaN        NaN         NaN       NaN          NaN            NaN
# 4        NaN        NaN         NaN       NaN          NaN            NaN
#
#   loc_kenia loc_kirguistan loc_kiribati loc_kuwait loc_laos loc_lesoto  \
# 0       NaN            NaN          NaN        NaN      NaN        NaN
# 1       NaN            NaN          NaN        NaN      NaN        NaN
# 2       NaN            NaN          NaN        NaN      NaN        NaN
# 3       NaN            NaN          NaN        NaN      NaN        NaN
# 4       NaN            NaN          NaN        NaN      NaN        NaN
#
#   loc_letonia loc_libano loc_liberia loc_libia loc_liechtenstein loc_lituania  \
# 0         NaN        NaN         NaN       NaN               NaN          NaN
# 1         NaN        NaN         NaN       NaN               NaN          NaN
# 2         NaN        NaN         NaN       NaN               NaN          NaN
# 3         NaN        NaN         NaN       NaN               NaN          NaN
# 4         NaN        NaN         NaN       NaN               NaN          NaN
#
#   loc_luxemburgo loc_macedoniadelnorte loc_madagascar loc_malasia loc_malaui  \
# 0            NaN                   NaN            NaN         NaN        NaN
# 1            NaN                   NaN            NaN         NaN        NaN
# 2            NaN                   NaN            NaN         NaN        NaN
# 3            NaN                   NaN            NaN         NaN        NaN
# 4            NaN                   NaN            NaN         NaN        NaN
#
#   loc_maldivas loc_malimali loc_malta loc_marruecos loc_islasmarshall  \
# 0          NaN          NaN       NaN           NaN               NaN
# 1          NaN          NaN       NaN           NaN               NaN
# 2          NaN          NaN       NaN           NaN               NaN
# 3          NaN          NaN       NaN           NaN               NaN
# 4          NaN          NaN       NaN           NaN               NaN
#
#   loc_mauricio loc_mauritania loc_mexico loc_micronesia loc_moldavia  \
# 0          NaN            NaN        NaN            NaN          NaN
# 1          NaN            NaN        NaN            NaN          NaN
# 2          NaN            NaN        NaN            NaN          NaN
# 3          NaN            NaN        NaN            NaN          NaN
# 4          NaN            NaN        NaN            NaN          NaN
#
#   loc_monaco loc_mongolia loc_montenegro loc_mozambique loc_namibia loc_nauru  \
# 0        NaN          NaN            NaN            NaN         NaN       NaN
# 1        NaN          NaN            NaN            NaN         NaN       NaN
# 2        NaN          NaN            NaN            NaN         NaN       NaN
# 3        NaN          NaN            NaN            NaN         NaN       NaN
# 4        NaN          NaN            NaN            NaN         NaN       NaN
#
#   loc_nepal loc_nicaragua loc_niger loc_nigeria loc_noruega  \
# 0       NaN           NaN       NaN         NaN         NaN
# 1       NaN           NaN       NaN         NaN         NaN
# 2       NaN           NaN       NaN         NaN         NaN
# 3       NaN           NaN       NaN         NaN         NaN
# 4       NaN           NaN       NaN         NaN         NaN
#
#   loc_nuevazelandanuevazelandia loc_oman loc_paisesbajos loc_pakistan  \
# 0                           NaN      NaN             NaN          NaN
# 1                           NaN      NaN             NaN          NaN
# 2                           NaN      NaN             NaN          NaN
# 3                           NaN      NaN             NaN          NaN
# 4                           NaN      NaN             NaN          NaN
#
#   loc_palaos loc_palestina loc_panama loc_papuanuevaguinea loc_paraguay  \
# 0        NaN           NaN        NaN                  NaN          NaN
# 1        NaN           NaN        NaN                  NaN          NaN
# 2        NaN           NaN        NaN                  NaN          NaN
# 3        NaN           NaN        NaN                  NaN          NaN
# 4        NaN           NaN        NaN                  NaN          NaN
#
#   loc_peru loc_polonia loc_portugal loc_reinounido loc_ruanda  \
# 0      NaN         NaN          NaN            NaN        NaN
# 1      NaN         NaN          NaN            NaN        NaN
# 2      NaN         NaN          NaN            NaN        NaN
# 3      NaN         NaN          NaN            NaN        NaN
# 4      NaN         NaN          NaN            NaN        NaN
#
#   loc_rumaniarumania loc_rusia loc_islassalomon loc_samoa  \
# 0                NaN       NaN              NaN       NaN
# 1                NaN       NaN              NaN       NaN
# 2                NaN       NaN              NaN       NaN
# 3                NaN       NaN              NaN       NaN
# 4                NaN       NaN              NaN       NaN
#
#   loc_sancristobalynieves loc_sanmarino loc_sanvicenteylasgranadinas  \
# 0                     NaN           NaN                          NaN
# 1                     NaN           NaN                          NaN
# 2                     NaN           NaN                          NaN
# 3                     NaN           NaN                          NaN
# 4                     NaN           NaN                          NaN
#
#   loc_santalucia loc_santotomeyprincipe loc_senegal loc_serbia loc_seychelles  \
# 0            NaN                    NaN         NaN        NaN            NaN
# 1            NaN                    NaN         NaN        NaN            NaN
# 2            NaN                    NaN         NaN        NaN            NaN
# 3            NaN                    NaN         NaN        NaN            NaN
# 4            NaN                    NaN         NaN        NaN            NaN
#
#   loc_sierraleona loc_singapur loc_siria loc_somalia loc_srilanka  \
# 0             NaN          NaN       NaN         NaN          NaN
# 1             NaN          NaN       NaN         NaN          NaN
# 2             NaN          NaN       NaN         NaN          NaN
# 3             NaN          NaN       NaN         NaN          NaN
# 4             NaN          NaN       NaN         NaN          NaN
#
#   loc_suazilandiaesuatini loc_sudafrica loc_sudan loc_sudandelsur loc_suecia  \
# 0                     NaN           NaN       NaN             NaN        NaN
# 1                     NaN           NaN       NaN             NaN        NaN
# 2                     NaN           NaN       NaN             NaN        NaN
# 3                     NaN           NaN       NaN             NaN        NaN
# 4                     NaN           NaN       NaN             NaN        NaN
#
#   loc_suiza loc_surinam loc_tailandia loc_tanzania loc_tayikistan  \
# 0       NaN         NaN           NaN          NaN            NaN
# 1       NaN         NaN           NaN          NaN            NaN
# 2       NaN         NaN           NaN          NaN            NaN
# 3       NaN         NaN           NaN          NaN            NaN
# 4       NaN         NaN           NaN          NaN            NaN
#
#   loc_timororiental loc_togo loc_tonga loc_trinidadytobago loc_tunez  \
# 0               NaN      NaN       NaN                 NaN       NaN
# 1               NaN      NaN       NaN                 NaN       NaN
# 2               NaN      NaN       NaN                 NaN       NaN
# 3               NaN      NaN       NaN                 NaN       NaN
# 4               NaN      NaN       NaN                 NaN       NaN
#
#   loc_turkmenistan loc_turquia loc_tuvalu loc_ucrania loc_uganda loc_uruguay  \
# 0              NaN         NaN        NaN         NaN        NaN         NaN
# 1              NaN         NaN        NaN         NaN        NaN         NaN
# 2              NaN         NaN        NaN         NaN        NaN         NaN
# 3              NaN         NaN        NaN         NaN        NaN         NaN
# 4              NaN         NaN        NaN         NaN        NaN         NaN
#
#   loc_uzbekistan loc_vanuatu loc_ciudaddelvaticano loc_venezuela loc_vietnam  \
# 0            NaN         NaN                   NaN           NaN         NaN
# 1            NaN         NaN                   NaN           NaN         NaN
# 2            NaN         NaN                   NaN           NaN         NaN
# 3            NaN         NaN                   NaN           NaN         NaN
# 4            NaN         NaN                   NaN           NaN         NaN
#
#   loc_yemen loc_yibuti loc_zambia loc_zimbabue
# 0       NaN        NaN        NaN          NaN
# 1       NaN        NaN        NaN          NaN
# 2       NaN        NaN        NaN          NaN
# 3       NaN        NaN        NaN          NaN
# 4       NaN        NaN        NaN          NaN

# %%
bio_regex_othercountry.head()
# Out:
#                     id      conversation_id   author_id  \
# 0  1513295387230019585  1512966960723595268   119939347
# 1  1513152998792327168  1512870302224723973  2209329607
# 2  1512902523190882308  1512240874842832898  2209329607
# 3  1512595129630171136  1512595129630171136    66169172
# 4  1512593335223005193  1512593335223005193    66169172
#
#    bio_any_other_country bio_afganistan bio_albania bio_alemania bio_andorra  \
# 0                  False            NaN         NaN          NaN         NaN
# 1                  False            NaN         NaN          NaN         NaN
# 2                  False            NaN         NaN          NaN         NaN
# 3                  False            NaN         NaN          NaN         NaN
# 4                  False            NaN         NaN          NaN         NaN
#
#   bio_angola bio_antiguaybarbuda bio_arabiasauditaarabiasaudi bio_argelia  \
# 0        NaN                 NaN                          NaN         NaN
# 1        NaN                 NaN                          NaN         NaN
# 2        NaN                 NaN                          NaN         NaN
# 3        NaN                 NaN                          NaN         NaN
# 4        NaN                 NaN                          NaN         NaN
#
#   bio_argentina bio_armenia bio_australia bio_austria bio_azerbaiyan  \
# 0           NaN         NaN           NaN         NaN            NaN
# 1           NaN         NaN           NaN         NaN            NaN
# 2           NaN         NaN           NaN         NaN            NaN
# 3           NaN         NaN           NaN         NaN            NaN
# 4           NaN         NaN           NaN         NaN            NaN
#
#   bio_bahamas bio_banglades bio_barbados bio_barein bio_belgica bio_belice  \
# 0         NaN           NaN          NaN        NaN         NaN        NaN
# 1         NaN           NaN          NaN        NaN         NaN        NaN
# 2         NaN           NaN          NaN        NaN         NaN        NaN
# 3         NaN           NaN          NaN        NaN         NaN        NaN
# 4         NaN           NaN          NaN        NaN         NaN        NaN
#
#   bio_benin bio_bielorrusia bio_birmaniamyanmar bio_bolivia  \
# 0       NaN             NaN                 NaN         NaN
# 1       NaN             NaN                 NaN         NaN
# 2       NaN             NaN                 NaN         NaN
# 3       NaN             NaN                 NaN         NaN
# 4       NaN             NaN                 NaN         NaN
#
#   bosniayherzegovinabosnia_herzegovina bio_botsuana bio_brasil bio_brunei  \
# 0                                  NaN          NaN        NaN        NaN
# 1                                  NaN          NaN        NaN        NaN
# 2                                  NaN          NaN        NaN        NaN
# 3                                  NaN          NaN        NaN        NaN
# 4                                  NaN          NaN        NaN        NaN
#
#   bio_bulgaria bio_burkinafaso bio_burundi bio_butan bio_caboverde  \
# 0          NaN             NaN         NaN       NaN           NaN
# 1          NaN             NaN         NaN       NaN           NaN
# 2          NaN             NaN         NaN       NaN           NaN
# 3          NaN             NaN         NaN       NaN           NaN
# 4          NaN             NaN         NaN       NaN           NaN
#
#   bio_camboya bio_camerun bio_canada bio_catar bio_republicacentroafricana  \
# 0         NaN         NaN        NaN       NaN                         NaN
# 1         NaN         NaN        NaN       NaN                         NaN
# 2         NaN         NaN        NaN       NaN                         NaN
# 3         NaN         NaN        NaN       NaN                         NaN
# 4         NaN         NaN        NaN       NaN                         NaN
#
#   bio_chad bio_republicachecachequia bio_chile bio_china bio_chipre  \
# 0      NaN                       NaN       NaN       NaN        NaN
# 1      NaN                       NaN       NaN       NaN        NaN
# 2      NaN                       NaN       NaN       NaN        NaN
# 3      NaN                       NaN       NaN       NaN        NaN
# 4      NaN                       NaN       NaN       NaN        NaN
#
#   bio_colombia bio_comoras bio_republicadelcongo  \
# 0          NaN         NaN                   NaN
# 1          NaN         NaN                   NaN
# 2          NaN         NaN                   NaN
# 3          NaN         NaN                   NaN
# 4          NaN         NaN                   NaN
#
#   bio_republicademocraticadelcongo bio_coreadelnorte bio_coreadelsur  \
# 0                              NaN               NaN             NaN
# 1                              NaN               NaN             NaN
# 2                              NaN               NaN             NaN
# 3                              NaN               NaN             NaN
# 4                              NaN               NaN             NaN
#
#   bio_costademarfil bio_costarica bio_croacia bio_cuba bio_dinamarca  \
# 0               NaN           NaN         NaN      NaN           NaN
# 1               NaN           NaN         NaN      NaN           NaN
# 2               NaN           NaN         NaN      NaN           NaN
# 3               NaN           NaN         NaN      NaN           NaN
# 4               NaN           NaN         NaN      NaN           NaN
#
#   bio_dominica bio_republicadominicana bio_ecuador bio_egipto bio_elsalvador  \
# 0          NaN                     NaN         NaN        NaN            NaN
# 1          NaN                     NaN         NaN        NaN            NaN
# 2          NaN                     NaN         NaN        NaN            NaN
# 3          NaN                     NaN         NaN        NaN            NaN
# 4          NaN                     NaN         NaN        NaN            NaN
#
#   bio_emiratosarabesunidos bio_eritrea bio_eslovaquia bio_eslovenia  \
# 0                      NaN         NaN            NaN           NaN
# 1                      NaN         NaN            NaN           NaN
# 2                      NaN         NaN            NaN           NaN
# 3                      NaN         NaN            NaN           NaN
# 4                      NaN         NaN            NaN           NaN
#
#   bio_espana bio_estadosunidos bio_estonia bio_etiopia bio_filipinas  \
# 0        NaN               NaN         NaN         NaN           NaN
# 1        NaN               NaN         NaN         NaN           NaN
# 2        NaN               NaN         NaN         NaN           NaN
# 3        NaN               NaN         NaN         NaN           NaN
# 4        NaN               NaN         NaN         NaN           NaN
#
#   bio_finlandia bio_fiyi bio_francia bio_gabon bio_gambia bio_georgia  \
# 0           NaN      NaN         NaN       NaN        NaN         NaN
# 1           NaN      NaN         NaN       NaN        NaN         NaN
# 2           NaN      NaN         NaN       NaN        NaN         NaN
# 3           NaN      NaN         NaN       NaN        NaN         NaN
# 4           NaN      NaN         NaN       NaN        NaN         NaN
#
#   bio_ghana bio_granada bio_grecia bio_guatemala bio_guinea guinea_bisau  \
# 0       NaN         NaN        NaN           NaN        NaN          NaN
# 1       NaN         NaN        NaN           NaN        NaN          NaN
# 2       NaN         NaN        NaN           NaN        NaN          NaN
# 3       NaN         NaN        NaN           NaN        NaN          NaN
# 4       NaN         NaN        NaN           NaN        NaN          NaN
#
#   bio_guineaecuatorial bio_guyana bio_haiti bio_honduras bio_hungria  \
# 0                  NaN        NaN       NaN          NaN         NaN
# 1                  NaN        NaN       NaN          NaN         NaN
# 2                  NaN        NaN       NaN          NaN         NaN
# 3                  NaN        NaN       NaN          NaN         NaN
# 4                  NaN        NaN       NaN          NaN         NaN
#
#   bio_india bio_indonesia bio_irak bio_iran bio_irlanda bio_islandia  \
# 0       NaN           NaN      NaN      NaN         NaN          NaN
# 1       NaN           NaN      NaN      NaN         NaN          NaN
# 2       NaN           NaN      NaN      NaN         NaN          NaN
# 3       NaN           NaN      NaN      NaN         NaN          NaN
# 4       NaN           NaN      NaN      NaN         NaN          NaN
#
#   bio_israel bio_italia bio_jamaica bio_japon bio_jordania bio_kazajistan  \
# 0        NaN        NaN         NaN       NaN          NaN            NaN
# 1        NaN        NaN         NaN       NaN          NaN            NaN
# 2        NaN        NaN         NaN       NaN          NaN            NaN
# 3        NaN        NaN         NaN       NaN          NaN            NaN
# 4        NaN        NaN         NaN       NaN          NaN            NaN
#
#   bio_kenia bio_kirguistan bio_kiribati bio_kuwait bio_laos bio_lesoto  \
# 0       NaN            NaN          NaN        NaN      NaN        NaN
# 1       NaN            NaN          NaN        NaN      NaN        NaN
# 2       NaN            NaN          NaN        NaN      NaN        NaN
# 3       NaN            NaN          NaN        NaN      NaN        NaN
# 4       NaN            NaN          NaN        NaN      NaN        NaN
#
#   bio_letonia bio_libano bio_liberia bio_libia bio_liechtenstein bio_lituania  \
# 0         NaN        NaN         NaN       NaN               NaN          NaN
# 1         NaN        NaN         NaN       NaN               NaN          NaN
# 2         NaN        NaN         NaN       NaN               NaN          NaN
# 3         NaN        NaN         NaN       NaN               NaN          NaN
# 4         NaN        NaN         NaN       NaN               NaN          NaN
#
#   bio_luxemburgo bio_macedoniadelnorte bio_madagascar bio_malasia bio_malaui  \
# 0            NaN                   NaN            NaN         NaN        NaN
# 1            NaN                   NaN            NaN         NaN        NaN
# 2            NaN                   NaN            NaN         NaN        NaN
# 3            NaN                   NaN            NaN         NaN        NaN
# 4            NaN                   NaN            NaN         NaN        NaN
#
#   bio_maldivas bio_malimali bio_malta bio_marruecos bio_islasmarshall  \
# 0          NaN          NaN       NaN           NaN               NaN
# 1          NaN          NaN       NaN           NaN               NaN
# 2          NaN          NaN       NaN           NaN               NaN
# 3          NaN          NaN       NaN           NaN               NaN
# 4          NaN          NaN       NaN           NaN               NaN
#
#   bio_mauricio bio_mauritania bio_mexico bio_micronesia bio_moldavia  \
# 0          NaN            NaN        NaN            NaN          NaN
# 1          NaN            NaN        NaN            NaN          NaN
# 2          NaN            NaN        NaN            NaN          NaN
# 3          NaN            NaN        NaN            NaN          NaN
# 4          NaN            NaN        NaN            NaN          NaN
#
#   bio_monaco bio_mongolia bio_montenegro bio_mozambique bio_namibia bio_nauru  \
# 0        NaN          NaN            NaN            NaN         NaN       NaN
# 1        NaN          NaN            NaN            NaN         NaN       NaN
# 2        NaN          NaN            NaN            NaN         NaN       NaN
# 3        NaN          NaN            NaN            NaN         NaN       NaN
# 4        NaN          NaN            NaN            NaN         NaN       NaN
#
#   bio_nepal bio_nicaragua bio_niger bio_nigeria bio_noruega  \
# 0       NaN           NaN       NaN         NaN         NaN
# 1       NaN           NaN       NaN         NaN         NaN
# 2       NaN           NaN       NaN         NaN         NaN
# 3       NaN           NaN       NaN         NaN         NaN
# 4       NaN           NaN       NaN         NaN         NaN
#
#   bio_nuevazelandanuevazelandia bio_oman bio_paisesbajos bio_pakistan  \
# 0                           NaN      NaN             NaN          NaN
# 1                           NaN      NaN             NaN          NaN
# 2                           NaN      NaN             NaN          NaN
# 3                           NaN      NaN             NaN          NaN
# 4                           NaN      NaN             NaN          NaN
#
#   bio_palaos bio_palestina bio_panama bio_papuanuevaguinea bio_paraguay  \
# 0        NaN           NaN        NaN                  NaN          NaN
# 1        NaN           NaN        NaN                  NaN          NaN
# 2        NaN           NaN        NaN                  NaN          NaN
# 3        NaN           NaN        NaN                  NaN          NaN
# 4        NaN           NaN        NaN                  NaN          NaN
#
#   bio_peru bio_polonia bio_portugal bio_reinounido bio_ruanda  \
# 0      NaN         NaN          NaN            NaN        NaN
# 1      NaN         NaN          NaN            NaN        NaN
# 2      NaN         NaN          NaN            NaN        NaN
# 3      NaN         NaN          NaN            NaN        NaN
# 4      NaN         NaN          NaN            NaN        NaN
#
#   bio_rumaniarumania bio_rusia bio_islassalomon bio_samoa  \
# 0                NaN       NaN              NaN       NaN
# 1                NaN       NaN              NaN       NaN
# 2                NaN       NaN              NaN       NaN
# 3                NaN       NaN              NaN       NaN
# 4                NaN       NaN              NaN       NaN
#
#   bio_sancristobalynieves bio_sanmarino bio_sanvicenteylasgranadinas  \
# 0                     NaN           NaN                          NaN
# 1                     NaN           NaN                          NaN
# 2                     NaN           NaN                          NaN
# 3                     NaN           NaN                          NaN
# 4                     NaN           NaN                          NaN
#
#   bio_santalucia bio_santotomeyprincipe bio_senegal bio_serbia bio_seychelles  \
# 0            NaN                    NaN         NaN        NaN            NaN
# 1            NaN                    NaN         NaN        NaN            NaN
# 2            NaN                    NaN         NaN        NaN            NaN
# 3            NaN                    NaN         NaN        NaN            NaN
# 4            NaN                    NaN         NaN        NaN            NaN
#
#   bio_sierraleona bio_singapur bio_siria bio_somalia bio_srilanka  \
# 0             NaN          NaN       NaN         NaN          NaN
# 1             NaN          NaN       NaN         NaN          NaN
# 2             NaN          NaN       NaN         NaN          NaN
# 3             NaN          NaN       NaN         NaN          NaN
# 4             NaN          NaN       NaN         NaN          NaN
#
#   bio_suazilandiaesuatini bio_sudafrica bio_sudan bio_sudandelsur bio_suecia  \
# 0                     NaN           NaN       NaN             NaN        NaN
# 1                     NaN           NaN       NaN             NaN        NaN
# 2                     NaN           NaN       NaN             NaN        NaN
# 3                     NaN           NaN       NaN             NaN        NaN
# 4                     NaN           NaN       NaN             NaN        NaN
#
#   bio_suiza bio_surinam bio_tailandia bio_tanzania bio_tayikistan  \
# 0       NaN         NaN           NaN          NaN            NaN
# 1       NaN         NaN           NaN          NaN            NaN
# 2       NaN         NaN           NaN          NaN            NaN
# 3       NaN         NaN           NaN          NaN            NaN
# 4       NaN         NaN           NaN          NaN            NaN
#
#   bio_timororiental bio_togo bio_tonga bio_trinidadytobago bio_tunez  \
# 0               NaN      NaN       NaN                 NaN       NaN
# 1               NaN      NaN       NaN                 NaN       NaN
# 2               NaN      NaN       NaN                 NaN       NaN
# 3               NaN      NaN       NaN                 NaN       NaN
# 4               NaN      NaN       NaN                 NaN       NaN
#
#   bio_turkmenistan bio_turquia bio_tuvalu bio_ucrania bio_uganda bio_uruguay  \
# 0              NaN         NaN        NaN         NaN        NaN         NaN
# 1              NaN         NaN        NaN         NaN        NaN         NaN
# 2              NaN         NaN        NaN         NaN        NaN         NaN
# 3              NaN         NaN        NaN         NaN        NaN         NaN
# 4              NaN         NaN        NaN         NaN        NaN         NaN
#
#   bio_uzbekistan bio_vanuatu bio_ciudaddelvaticano bio_venezuela bio_vietnam  \
# 0            NaN         NaN                   NaN           NaN         NaN
# 1            NaN         NaN                   NaN           NaN         NaN
# 2            NaN         NaN                   NaN           NaN         NaN
# 3            NaN         NaN                   NaN           NaN         NaN
# 4            NaN         NaN                   NaN           NaN         NaN
#
#   bio_yemen bio_yibuti bio_zambia bio_zimbabue
# 0       NaN        NaN        NaN          NaN
# 1       NaN        NaN        NaN          NaN
# 2       NaN        NaN        NaN          NaN
# 3       NaN        NaN        NaN          NaN
# 4       NaN        NaN        NaN          NaN

# %% [markdown]
# ### 1.5.4 Dictionary Method: Chilean Cities

# %%
loc_city_ngram.head()
# Out:
#                     id      conversation_id   author_id  loc_any_ngram_city  \
# 0  1513295387230019585  1512966960723595268   119939347               False
# 1  1513152998792327168  1512870302224723973  2209329607               False
# 2  1512902523190882308  1512240874842832898  2209329607               False
# 3  1512595129630171136  1512595129630171136    66169172               False
# 4  1512593335223005193  1512593335223005193    66169172               False
#
#   loc_alto_hospicio loc_alto_jahuel loc_ancud loc_andacollo loc_angol  \
# 0               NaN             NaN       NaN           NaN       NaN
# 1               NaN             NaN       NaN           NaN       NaN
# 2               NaN             NaN       NaN           NaN       NaN
# 3               NaN             NaN       NaN           NaN       NaN
# 4               NaN             NaN       NaN           NaN       NaN
#
#   loc_antofagasta loc_araucania loc_arauco loc_arica  \
# 0             NaN           NaN        NaN       NaN
# 1             NaN           NaN        NaN       NaN
# 2             NaN           NaN        NaN       NaN
# 3             NaN           NaN        NaN       NaN
# 4             NaN           NaN        NaN       NaN
#
#   loc_arica_and_parinacota_region loc_atacama loc_aysen  \
# 0                             NaN         NaN       NaN
# 1                             NaN         NaN       NaN
# 2                             NaN         NaN       NaN
# 3                             NaN         NaN       NaN
# 4                             NaN         NaN       NaN
#
#   loc_bajos_de_san_agustin loc_biobio loc_buin loc_cabrero loc_calama  \
# 0                      NaN        NaN      NaN         NaN        NaN
# 1                      NaN        NaN      NaN         NaN        NaN
# 2                      NaN        NaN      NaN         NaN        NaN
# 3                      NaN        NaN      NaN         NaN        NaN
# 4                      NaN        NaN      NaN         NaN        NaN
#
#   loc_calbuco loc_canete loc_carahue loc_catemu loc_cauquenes loc_cerrillos  \
# 0         NaN        NaN         NaN        NaN           NaN           NaN
# 1         NaN        NaN         NaN        NaN           NaN           NaN
# 2         NaN        NaN         NaN        NaN           NaN           NaN
# 3         NaN        NaN         NaN        NaN           NaN           NaN
# 4         NaN        NaN         NaN        NaN           NaN           NaN
#
#   loc_cerro_navia loc_chanaral loc_chiguayante loc_chillan loc_chillan_viejo  \
# 0             NaN          NaN             NaN         NaN               NaN
# 1             NaN          NaN             NaN         NaN               NaN
# 2             NaN          NaN             NaN         NaN               NaN
# 3             NaN          NaN             NaN         NaN               NaN
# 4             NaN          NaN             NaN         NaN               NaN
#
#   loc_chimbarongo loc_chuquicamata loc_codegua loc_coelemu loc_coihueco  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2             NaN              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4             NaN              NaN         NaN         NaN          NaN
#
#   loc_collipulli loc_combarbala loc_conchali loc_concon loc_copiapo  \
# 0            NaN            NaN          NaN        NaN         NaN
# 1            NaN            NaN          NaN        NaN         NaN
# 2            NaN            NaN          NaN        NaN         NaN
# 3            NaN            NaN          NaN        NaN         NaN
# 4            NaN            NaN          NaN        NaN         NaN
#
#   loc_coquimbo loc_coyhaique loc_cunco loc_curacautin loc_curacavi  \
# 0          NaN           NaN       NaN            NaN          NaN
# 1          NaN           NaN       NaN            NaN          NaN
# 2          NaN           NaN       NaN            NaN          NaN
# 3          NaN           NaN       NaN            NaN          NaN
# 4          NaN           NaN       NaN            NaN          NaN
#
#   loc_curanilahue loc_curico loc_donihue loc_el_palqui loc_el_quisco  \
# 0             NaN        NaN         NaN           NaN           NaN
# 1             NaN        NaN         NaN           NaN           NaN
# 2             NaN        NaN         NaN           NaN           NaN
# 3             NaN        NaN         NaN           NaN           NaN
# 4             NaN        NaN         NaN           NaN           NaN
#
#   loc_el_tabo loc_estacion_zaldivar loc_frutillar loc_futrono loc_gultro  \
# 0         NaN                   NaN           NaN         NaN        NaN
# 1         NaN                   NaN           NaN         NaN        NaN
# 2         NaN                   NaN           NaN         NaN        NaN
# 3         NaN                   NaN           NaN         NaN        NaN
# 4         NaN                   NaN           NaN         NaN        NaN
#
#   loc_hijuelas loc_hualane loc_hualpen loc_hualqui loc_huasco loc_huechuraba  \
# 0          NaN         NaN         NaN         NaN        NaN            NaN
# 1          NaN         NaN         NaN         NaN        NaN            NaN
# 2          NaN         NaN         NaN         NaN        NaN            NaN
# 3          NaN         NaN         NaN         NaN        NaN            NaN
# 4          NaN         NaN         NaN         NaN        NaN            NaN
#
#   loc_huepil loc_illapel loc_iquique loc_isla_de_maipo loc_la_cisterna  \
# 0        NaN         NaN         NaN               NaN             NaN
# 1        NaN         NaN         NaN               NaN             NaN
# 2        NaN         NaN         NaN               NaN             NaN
# 3        NaN         NaN         NaN               NaN             NaN
# 4        NaN         NaN         NaN               NaN             NaN
#
#   loc_la_ligua loc_la_pintana loc_lanco loc_las_condes loc_lebu loc_limache  \
# 0          NaN            NaN       NaN            NaN      NaN         NaN
# 1          NaN            NaN       NaN            NaN      NaN         NaN
# 2          NaN            NaN       NaN            NaN      NaN         NaN
# 3          NaN            NaN       NaN            NaN      NaN         NaN
# 4          NaN            NaN       NaN            NaN      NaN         NaN
#
#   loc_llanquihue loc_llay_llay loc_lo_barnechea loc_lo_miranda loc_lo_prado  \
# 0            NaN           NaN              NaN            NaN          NaN
# 1            NaN           NaN              NaN            NaN          NaN
# 2            NaN           NaN              NaN            NaN          NaN
# 3            NaN           NaN              NaN            NaN          NaN
# 4            NaN           NaN              NaN            NaN          NaN
#
#   loc_loncoche loc_longavi loc_los_muermos loc_los_vilos loc_machali  \
# 0          NaN         NaN             NaN           NaN         NaN
# 1          NaN         NaN             NaN           NaN         NaN
# 2          NaN         NaN             NaN           NaN         NaN
# 3          NaN         NaN             NaN           NaN         NaN
# 4          NaN         NaN             NaN           NaN         NaN
#
#   loc_macul loc_maipu loc_mariquina loc_maule loc_melipilla loc_monte_aguila  \
# 0       NaN       NaN           NaN       NaN           NaN              NaN
# 1       NaN       NaN           NaN       NaN           NaN              NaN
# 2       NaN       NaN           NaN       NaN           NaN              NaN
# 3       NaN       NaN           NaN       NaN           NaN              NaN
# 4       NaN       NaN           NaN       NaN           NaN              NaN
#
#   loc_monte_patria loc_mulchen loc_nancagua loc_nueva_imperial loc_nunoa  \
# 0              NaN         NaN          NaN                NaN       NaN
# 1              NaN         NaN          NaN                NaN       NaN
# 2              NaN         NaN          NaN                NaN       NaN
# 3              NaN         NaN          NaN                NaN       NaN
# 4              NaN         NaN          NaN                NaN       NaN
#
#   loc_o'higgins loc_olmue loc_ovalle loc_padre_las_casas loc_paillaco  \
# 0           NaN       NaN        NaN                 NaN          NaN
# 1           NaN       NaN        NaN                 NaN          NaN
# 2           NaN       NaN        NaN                 NaN          NaN
# 3           NaN       NaN        NaN                 NaN          NaN
# 4           NaN       NaN        NaN                 NaN          NaN
#
#   loc_paine loc_panguipulli loc_parral loc_penalolen loc_pichilemu loc_pirque  \
# 0       NaN             NaN        NaN           NaN           NaN        NaN
# 1       NaN             NaN        NaN           NaN           NaN        NaN
# 2       NaN             NaN        NaN           NaN           NaN        NaN
# 3       NaN             NaN        NaN           NaN           NaN        NaN
# 4       NaN             NaN        NaN           NaN           NaN        NaN
#
#   loc_pitrufquen loc_placilla_de_penuelas loc_pozo_almonte loc_pucon  \
# 0            NaN                      NaN              NaN       NaN
# 1            NaN                      NaN              NaN       NaN
# 2            NaN                      NaN              NaN       NaN
# 3            NaN                      NaN              NaN       NaN
# 4            NaN                      NaN              NaN       NaN
#
#   loc_pudahuel loc_puente_alto loc_puerto_aysen loc_puerto_montt  \
# 0          NaN             NaN              NaN              NaN
# 1          NaN             NaN              NaN              NaN
# 2          NaN             NaN              NaN              NaN
# 3          NaN             NaN              NaN              NaN
# 4          NaN             NaN              NaN              NaN
#
#   loc_puerto_natales loc_puerto_varas loc_punta_arenas loc_puren  \
# 0                NaN              NaN              NaN       NaN
# 1                NaN              NaN              NaN       NaN
# 2                NaN              NaN              NaN       NaN
# 3                NaN              NaN              NaN       NaN
# 4                NaN              NaN              NaN       NaN
#
#   loc_purranque loc_putaendo loc_quellon loc_quilicura loc_quillon  \
# 0           NaN          NaN         NaN           NaN         NaN
# 1           NaN          NaN         NaN           NaN         NaN
# 2           NaN          NaN         NaN           NaN         NaN
# 3           NaN          NaN         NaN           NaN         NaN
# 4           NaN          NaN         NaN           NaN         NaN
#
#   loc_quillota loc_quilpue loc_quinta_de_tilcoco loc_quinta_normal  \
# 0          NaN         NaN                   NaN               NaN
# 1          NaN         NaN                   NaN               NaN
# 2          NaN         NaN                   NaN               NaN
# 3          NaN         NaN                   NaN               NaN
# 4          NaN         NaN                   NaN               NaN
#
#   loc_quirihue loc_rancagua loc_renaico loc_renca loc_requinoa loc_rinconada  \
# 0          NaN          NaN         NaN       NaN          NaN           NaN
# 1          NaN          NaN         NaN       NaN          NaN           NaN
# 2          NaN          NaN         NaN       NaN          NaN           NaN
# 3          NaN          NaN         NaN       NaN          NaN           NaN
# 4          NaN          NaN         NaN       NaN          NaN           NaN
#
#   loc_san_jose_de_maipo loc_san_pedro_de_la_paz  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN
#
#   loc_san_vicente_de_tagua_tagua loc_santiago loc_santiago_metropolitan  \
# 0                            NaN          NaN                       NaN
# 1                            NaN          NaN                       NaN
# 2                            NaN          NaN                       NaN
# 3                            NaN          NaN                       NaN
# 4                            NaN          NaN                       NaN
#
#   loc_santiago_metropolitan_region loc_talagante loc_talca loc_talcahuano  \
# 0                              NaN           NaN       NaN            NaN
# 1                              NaN           NaN       NaN            NaN
# 2                              NaN           NaN       NaN            NaN
# 3                              NaN           NaN       NaN            NaN
# 4                              NaN           NaN       NaN            NaN
#
#   loc_taltal loc_tarapaca loc_temuco loc_tierra_amarilla loc_tiltil  \
# 0        NaN          NaN        NaN                 NaN        NaN
# 1        NaN          NaN        NaN                 NaN        NaN
# 2        NaN          NaN        NaN                 NaN        NaN
# 3        NaN          NaN        NaN                 NaN        NaN
# 4        NaN          NaN        NaN                 NaN        NaN
#
#   loc_tocopilla loc_traiguen loc_valdivia loc_vallenar loc_valparaiso  \
# 0           NaN          NaN          NaN          NaN            NaN
# 1           NaN          NaN          NaN          NaN            NaN
# 2           NaN          NaN          NaN          NaN            NaN
# 3           NaN          NaN          NaN          NaN            NaN
# 4           NaN          NaN          NaN          NaN            NaN
#
#   loc_villa_alegre loc_villa_alemana loc_villarrica loc_vina_del_mar  \
# 0              NaN               NaN            NaN              NaN
# 1              NaN               NaN            NaN              NaN
# 2              NaN               NaN            NaN              NaN
# 3              NaN               NaN            NaN              NaN
# 4              NaN               NaN            NaN              NaN
#
#   loc_vitacura loc_yumbel
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
bio_city_ngram.head()
# Out:
#                     id      conversation_id   author_id  bio_any_ngram_city  \
# 0  1513295387230019585  1512966960723595268   119939347               False
# 1  1513152998792327168  1512870302224723973  2209329607               False
# 2  1512902523190882308  1512240874842832898  2209329607               False
# 3  1512595129630171136  1512595129630171136    66169172               False
# 4  1512593335223005193  1512593335223005193    66169172               False
#
#   bio_alto_hospicio bio_alto_jahuel bio_ancud bio_andacollo bio_angol  \
# 0               NaN             NaN       NaN           NaN       NaN
# 1               NaN             NaN       NaN           NaN       NaN
# 2               NaN             NaN       NaN           NaN       NaN
# 3               NaN             NaN       NaN           NaN       NaN
# 4               NaN             NaN       NaN           NaN       NaN
#
#   bio_antofagasta bio_araucania bio_arauco bio_arica  \
# 0             NaN           NaN        NaN       NaN
# 1             NaN           NaN        NaN       NaN
# 2             NaN           NaN        NaN       NaN
# 3             NaN           NaN        NaN       NaN
# 4             NaN           NaN        NaN       NaN
#
#   bio_arica_and_parinacota_region bio_atacama bio_aysen  \
# 0                             NaN         NaN       NaN
# 1                             NaN         NaN       NaN
# 2                             NaN         NaN       NaN
# 3                             NaN         NaN       NaN
# 4                             NaN         NaN       NaN
#
#   bio_bajos_de_san_agustin bio_biobio bio_buin bio_cabrero bio_calama  \
# 0                      NaN        NaN      NaN         NaN        NaN
# 1                      NaN        NaN      NaN         NaN        NaN
# 2                      NaN        NaN      NaN         NaN        NaN
# 3                      NaN        NaN      NaN         NaN        NaN
# 4                      NaN        NaN      NaN         NaN        NaN
#
#   bio_calbuco bio_canete bio_carahue bio_catemu bio_cauquenes bio_cerrillos  \
# 0         NaN        NaN         NaN        NaN           NaN           NaN
# 1         NaN        NaN         NaN        NaN           NaN           NaN
# 2         NaN        NaN         NaN        NaN           NaN           NaN
# 3         NaN        NaN         NaN        NaN           NaN           NaN
# 4         NaN        NaN         NaN        NaN           NaN           NaN
#
#   bio_cerro_navia bio_chanaral bio_chiguayante bio_chillan bio_chillan_viejo  \
# 0             NaN          NaN             NaN         NaN               NaN
# 1             NaN          NaN             NaN         NaN               NaN
# 2             NaN          NaN             NaN         NaN               NaN
# 3             NaN          NaN             NaN         NaN               NaN
# 4             NaN          NaN             NaN         NaN               NaN
#
#   bio_chimbarongo bio_chuquicamata bio_codegua bio_coelemu bio_coihueco  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2             NaN              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4             NaN              NaN         NaN         NaN          NaN
#
#   bio_collipulli bio_combarbala bio_conchali bio_concon bio_copiapo  \
# 0            NaN            NaN          NaN        NaN         NaN
# 1            NaN            NaN          NaN        NaN         NaN
# 2            NaN            NaN          NaN        NaN         NaN
# 3            NaN            NaN          NaN        NaN         NaN
# 4            NaN            NaN          NaN        NaN         NaN
#
#   bio_coquimbo bio_coyhaique bio_cunco bio_curacautin bio_curacavi  \
# 0          NaN           NaN       NaN            NaN          NaN
# 1          NaN           NaN       NaN            NaN          NaN
# 2          NaN           NaN       NaN            NaN          NaN
# 3          NaN           NaN       NaN            NaN          NaN
# 4          NaN           NaN       NaN            NaN          NaN
#
#   bio_curanilahue bio_curico bio_donihue bio_el_palqui bio_el_quisco  \
# 0             NaN        NaN         NaN           NaN           NaN
# 1             NaN        NaN         NaN           NaN           NaN
# 2             NaN        NaN         NaN           NaN           NaN
# 3             NaN        NaN         NaN           NaN           NaN
# 4             NaN        NaN         NaN           NaN           NaN
#
#   bio_el_tabo bio_estacion_zaldivar bio_frutillar bio_futrono bio_gultro  \
# 0         NaN                   NaN           NaN         NaN        NaN
# 1         NaN                   NaN           NaN         NaN        NaN
# 2         NaN                   NaN           NaN         NaN        NaN
# 3         NaN                   NaN           NaN         NaN        NaN
# 4         NaN                   NaN           NaN         NaN        NaN
#
#   bio_hijuelas bio_hualane bio_hualpen bio_hualqui bio_huasco bio_huechuraba  \
# 0          NaN         NaN         NaN         NaN        NaN            NaN
# 1          NaN         NaN         NaN         NaN        NaN            NaN
# 2          NaN         NaN         NaN         NaN        NaN            NaN
# 3          NaN         NaN         NaN         NaN        NaN            NaN
# 4          NaN         NaN         NaN         NaN        NaN            NaN
#
#   bio_huepil bio_illapel bio_iquique bio_isla_de_maipo bio_la_cisterna  \
# 0        NaN         NaN         NaN               NaN             NaN
# 1        NaN         NaN         NaN               NaN             NaN
# 2        NaN         NaN         NaN               NaN             NaN
# 3        NaN         NaN         NaN               NaN             NaN
# 4        NaN         NaN         NaN               NaN             NaN
#
#   bio_la_ligua bio_la_pintana bio_lanco bio_las_condes bio_lebu bio_limache  \
# 0          NaN            NaN       NaN            NaN      NaN         NaN
# 1          NaN            NaN       NaN            NaN      NaN         NaN
# 2          NaN            NaN       NaN            NaN      NaN         NaN
# 3          NaN            NaN       NaN            NaN      NaN         NaN
# 4          NaN            NaN       NaN            NaN      NaN         NaN
#
#   bio_llanquihue bio_llay_llay bio_lo_barnechea bio_lo_miranda bio_lo_prado  \
# 0            NaN           NaN              NaN            NaN          NaN
# 1            NaN           NaN              NaN            NaN          NaN
# 2            NaN           NaN              NaN            NaN          NaN
# 3            NaN           NaN              NaN            NaN          NaN
# 4            NaN           NaN              NaN            NaN          NaN
#
#   bio_loncoche bio_longavi bio_los_muermos bio_los_vilos bio_machali  \
# 0          NaN         NaN             NaN           NaN         NaN
# 1          NaN         NaN             NaN           NaN         NaN
# 2          NaN         NaN             NaN           NaN         NaN
# 3          NaN         NaN             NaN           NaN         NaN
# 4          NaN         NaN             NaN           NaN         NaN
#
#   bio_macul bio_maipu bio_mariquina bio_maule bio_melipilla bio_monte_aguila  \
# 0       NaN       NaN           NaN       NaN           NaN              NaN
# 1       NaN       NaN           NaN       NaN           NaN              NaN
# 2       NaN       NaN           NaN       NaN           NaN              NaN
# 3       NaN       NaN           NaN       NaN           NaN              NaN
# 4       NaN       NaN           NaN       NaN           NaN              NaN
#
#   bio_monte_patria bio_mulchen bio_nancagua bio_nueva_imperial bio_nunoa  \
# 0              NaN         NaN          NaN                NaN       NaN
# 1              NaN         NaN          NaN                NaN       NaN
# 2              NaN         NaN          NaN                NaN       NaN
# 3              NaN         NaN          NaN                NaN       NaN
# 4              NaN         NaN          NaN                NaN       NaN
#
#   bio_o'higgins bio_olmue bio_ovalle bio_padre_las_casas bio_paillaco  \
# 0           NaN       NaN        NaN                 NaN          NaN
# 1           NaN       NaN        NaN                 NaN          NaN
# 2           NaN       NaN        NaN                 NaN          NaN
# 3           NaN       NaN        NaN                 NaN          NaN
# 4           NaN       NaN        NaN                 NaN          NaN
#
#   bio_paine bio_panguipulli bio_parral bio_penalolen bio_pichilemu bio_pirque  \
# 0       NaN             NaN        NaN           NaN           NaN        NaN
# 1       NaN             NaN        NaN           NaN           NaN        NaN
# 2       NaN             NaN        NaN           NaN           NaN        NaN
# 3       NaN             NaN        NaN           NaN           NaN        NaN
# 4       NaN             NaN        NaN           NaN           NaN        NaN
#
#   bio_pitrufquen bio_placilla_de_penuelas bio_pozo_almonte bio_pucon  \
# 0            NaN                      NaN              NaN       NaN
# 1            NaN                      NaN              NaN       NaN
# 2            NaN                      NaN              NaN       NaN
# 3            NaN                      NaN              NaN       NaN
# 4            NaN                      NaN              NaN       NaN
#
#   bio_pudahuel bio_puente_alto bio_puerto_aysen bio_puerto_montt  \
# 0          NaN             NaN              NaN              NaN
# 1          NaN             NaN              NaN              NaN
# 2          NaN             NaN              NaN              NaN
# 3          NaN             NaN              NaN              NaN
# 4          NaN             NaN              NaN              NaN
#
#   bio_puerto_natales bio_puerto_varas bio_punta_arenas bio_puren  \
# 0                NaN              NaN              NaN       NaN
# 1                NaN              NaN              NaN       NaN
# 2                NaN              NaN              NaN       NaN
# 3                NaN              NaN              NaN       NaN
# 4                NaN              NaN              NaN       NaN
#
#   bio_purranque bio_putaendo bio_quellon bio_quilicura bio_quillon  \
# 0           NaN          NaN         NaN           NaN         NaN
# 1           NaN          NaN         NaN           NaN         NaN
# 2           NaN          NaN         NaN           NaN         NaN
# 3           NaN          NaN         NaN           NaN         NaN
# 4           NaN          NaN         NaN           NaN         NaN
#
#   bio_quillota bio_quilpue bio_quinta_de_tilcoco bio_quinta_normal  \
# 0          NaN         NaN                   NaN               NaN
# 1          NaN         NaN                   NaN               NaN
# 2          NaN         NaN                   NaN               NaN
# 3          NaN         NaN                   NaN               NaN
# 4          NaN         NaN                   NaN               NaN
#
#   bio_quirihue bio_rancagua bio_renaico bio_renca bio_requinoa bio_rinconada  \
# 0          NaN          NaN         NaN       NaN          NaN           NaN
# 1          NaN          NaN         NaN       NaN          NaN           NaN
# 2          NaN          NaN         NaN       NaN          NaN           NaN
# 3          NaN          NaN         NaN       NaN          NaN           NaN
# 4          NaN          NaN         NaN       NaN          NaN           NaN
#
#   bio_san_jose_de_maipo bio_san_pedro_de_la_paz  \
# 0                   NaN                     NaN
# 1                   NaN                     NaN
# 2                   NaN                     NaN
# 3                   NaN                     NaN
# 4                   NaN                     NaN
#
#   bio_san_vicente_de_tagua_tagua bio_santiago bio_santiago_metropolitan  \
# 0                            NaN          NaN                       NaN
# 1                            NaN          NaN                       NaN
# 2                            NaN          NaN                       NaN
# 3                            NaN          NaN                       NaN
# 4                            NaN          NaN                       NaN
#
#   bio_santiago_metropolitan_region bio_talagante bio_talca bio_talcahuano  \
# 0                              NaN           NaN       NaN            NaN
# 1                              NaN           NaN       NaN            NaN
# 2                              NaN           NaN       NaN            NaN
# 3                              NaN           NaN       NaN            NaN
# 4                              NaN           NaN       NaN            NaN
#
#   bio_taltal bio_tarapaca bio_temuco bio_tierra_amarilla bio_tiltil  \
# 0        NaN          NaN        NaN                 NaN        NaN
# 1        NaN          NaN        NaN                 NaN        NaN
# 2        NaN          NaN        NaN                 NaN        NaN
# 3        NaN          NaN        NaN                 NaN        NaN
# 4        NaN          NaN        NaN                 NaN        NaN
#
#   bio_tocopilla bio_traiguen bio_valdivia bio_vallenar bio_valparaiso  \
# 0           NaN          NaN          NaN          NaN            NaN
# 1           NaN          NaN          NaN          NaN            NaN
# 2           NaN          NaN          NaN          NaN            NaN
# 3           NaN          NaN          NaN          NaN            NaN
# 4           NaN          NaN          NaN          NaN            NaN
#
#   bio_villa_alegre bio_villa_alemana bio_villarrica bio_vina_del_mar  \
# 0              NaN               NaN            NaN              NaN
# 1              NaN               NaN            NaN              NaN
# 2              NaN               NaN            NaN              NaN
# 3              NaN               NaN            NaN              NaN
# 4              NaN               NaN            NaN              NaN
#
#   bio_vitacura bio_yumbel
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
loc_city_unigram.head()
# Out:
#                     id      conversation_id   author_id  loc_any_unigram_city  \
# 0  1513295387230019585  1512966960723595268   119939347                 False
# 1  1513152998792327168  1512870302224723973  2209329607                 False
# 2  1512902523190882308  1512240874842832898  2209329607                 False
# 3  1512595129630171136  1512595129630171136    66169172                 False
# 4  1512593335223005193  1512593335223005193    66169172                 False
#
#   loc_ancud loc_andacollo loc_angol loc_antofagasta loc_araucania loc_arauco  \
# 0       NaN           NaN       NaN             NaN           NaN        NaN
# 1       NaN           NaN       NaN             NaN           NaN        NaN
# 2       NaN           NaN       NaN             NaN           NaN        NaN
# 3       NaN           NaN       NaN             NaN           NaN        NaN
# 4       NaN           NaN       NaN             NaN           NaN        NaN
#
#   loc_arica loc_atacama loc_aysen loc_barnechea loc_biobio loc_buin  \
# 0       NaN         NaN       NaN           NaN        NaN      NaN
# 1       NaN         NaN       NaN           NaN        NaN      NaN
# 2       NaN         NaN       NaN           NaN        NaN      NaN
# 3       NaN         NaN       NaN           NaN        NaN      NaN
# 4       NaN         NaN       NaN           NaN        NaN      NaN
#
#   loc_calama loc_calbuco loc_calera loc_canete loc_carahue loc_catemu  \
# 0        NaN         NaN        NaN        NaN         NaN        NaN
# 1        NaN         NaN        NaN        NaN         NaN        NaN
# 2        NaN         NaN        NaN        NaN         NaN        NaN
# 3        NaN         NaN        NaN        NaN         NaN        NaN
# 4        NaN         NaN        NaN        NaN         NaN        NaN
#
#   loc_cauquenes loc_cerrillos loc_chanaral loc_chiguayante loc_chillan  \
# 0           NaN           NaN          NaN             NaN         NaN
# 1           NaN           NaN          NaN             NaN         NaN
# 2           NaN           NaN          NaN             NaN         NaN
# 3           NaN           NaN          NaN             NaN         NaN
# 4           NaN           NaN          NaN             NaN         NaN
#
#   loc_chimbarongo loc_chuquicamata loc_codegua loc_coelemu loc_coihueco  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2             NaN              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4             NaN              NaN         NaN         NaN          NaN
#
#   loc_collipulli loc_combarbala loc_conchali loc_concon loc_copiapo  \
# 0            NaN            NaN          NaN        NaN         NaN
# 1            NaN            NaN          NaN        NaN         NaN
# 2            NaN            NaN          NaN        NaN         NaN
# 3            NaN            NaN          NaN        NaN         NaN
# 4            NaN            NaN          NaN        NaN         NaN
#
#   loc_coquimbo loc_coyhaique loc_cunco loc_curacautin loc_curacavi  \
# 0          NaN           NaN       NaN            NaN          NaN
# 1          NaN           NaN       NaN            NaN          NaN
# 2          NaN           NaN       NaN            NaN          NaN
# 3          NaN           NaN       NaN            NaN          NaN
# 4          NaN           NaN       NaN            NaN          NaN
#
#   loc_curanilahue loc_curico loc_donihue loc_frutillar loc_futrono  \
# 0             NaN        NaN         NaN           NaN         NaN
# 1             NaN        NaN         NaN           NaN         NaN
# 2             NaN        NaN         NaN           NaN         NaN
# 3             NaN        NaN         NaN           NaN         NaN
# 4             NaN        NaN         NaN           NaN         NaN
#
#   loc_graneros loc_gultro loc_hijuelas loc_hualane loc_hualpen loc_hualqui  \
# 0          NaN        NaN          NaN         NaN         NaN         NaN
# 1          NaN        NaN          NaN         NaN         NaN         NaN
# 2          NaN        NaN          NaN         NaN         NaN         NaN
# 3          NaN        NaN          NaN         NaN         NaN         NaN
# 4          NaN        NaN          NaN         NaN         NaN         NaN
#
#   loc_huasco loc_huechuraba loc_huepil loc_illapel loc_iquique loc_lanco  \
# 0        NaN            NaN        NaN         NaN         NaN       NaN
# 1        NaN            NaN        NaN         NaN         NaN       NaN
# 2        NaN            NaN        NaN         NaN         NaN       NaN
# 3        NaN            NaN        NaN         NaN         NaN       NaN
# 4        NaN            NaN        NaN         NaN         NaN       NaN
#
#   loc_lebu loc_ligua loc_limache loc_llanquihue loc_llay-llay loc_loncoche  \
# 0      NaN       NaN         NaN            NaN           NaN          NaN
# 1      NaN       NaN         NaN            NaN           NaN          NaN
# 2      NaN       NaN         NaN            NaN           NaN          NaN
# 3      NaN       NaN         NaN            NaN           NaN          NaN
# 4      NaN       NaN         NaN            NaN           NaN          NaN
#
#   loc_longavi loc_machali loc_macul loc_maipo loc_maipu loc_mariquina  \
# 0         NaN         NaN       NaN       NaN       NaN           NaN
# 1         NaN         NaN       NaN       NaN       NaN           NaN
# 2         NaN         NaN       NaN       NaN       NaN           NaN
# 3         NaN         NaN       NaN       NaN       NaN           NaN
# 4         NaN         NaN       NaN       NaN       NaN           NaN
#
#   loc_maule loc_melipilla loc_muermos loc_mulchen loc_nancagua loc_nunoa  \
# 0       NaN           NaN         NaN         NaN          NaN       NaN
# 1       NaN           NaN         NaN         NaN          NaN       NaN
# 2       NaN           NaN         NaN         NaN          NaN       NaN
# 3       NaN           NaN         NaN         NaN          NaN       NaN
# 4       NaN           NaN         NaN         NaN          NaN       NaN
#
#   loc_o'higgins loc_olmue loc_ovalle loc_paillaco loc_paine loc_panguipulli  \
# 0           NaN       NaN        NaN          NaN       NaN             NaN
# 1           NaN       NaN        NaN          NaN       NaN             NaN
# 2           NaN       NaN        NaN          NaN       NaN             NaN
# 3           NaN       NaN        NaN          NaN       NaN             NaN
# 4           NaN       NaN        NaN          NaN       NaN             NaN
#
#   loc_parinacota loc_penalolen loc_pichilemu loc_pintana loc_pirque  \
# 0            NaN           NaN           NaN         NaN        NaN
# 1            NaN           NaN           NaN         NaN        NaN
# 2            NaN           NaN           NaN         NaN        NaN
# 3            NaN           NaN           NaN         NaN        NaN
# 4            NaN           NaN           NaN         NaN        NaN
#
#   loc_pitrufquen loc_placilla loc_pucon loc_pudahuel loc_puren loc_purranque  \
# 0            NaN          NaN       NaN          NaN       NaN           NaN
# 1            NaN          NaN       NaN          NaN       NaN           NaN
# 2            NaN          NaN       NaN          NaN       NaN           NaN
# 3            NaN          NaN       NaN          NaN       NaN           NaN
# 4            NaN          NaN       NaN          NaN       NaN           NaN
#
#   loc_putaendo loc_quellon loc_quilicura loc_quillon loc_quillota loc_quilpue  \
# 0          NaN         NaN           NaN         NaN          NaN         NaN
# 1          NaN         NaN           NaN         NaN          NaN         NaN
# 2          NaN         NaN           NaN         NaN          NaN         NaN
# 3          NaN         NaN           NaN         NaN          NaN         NaN
# 4          NaN         NaN           NaN         NaN          NaN         NaN
#
#   loc_quirihue loc_quisco loc_rancagua loc_renaico loc_renca loc_requinoa  \
# 0          NaN        NaN          NaN         NaN       NaN          NaN
# 1          NaN        NaN          NaN         NaN       NaN          NaN
# 2          NaN        NaN          NaN         NaN       NaN          NaN
# 3          NaN        NaN          NaN         NaN       NaN          NaN
# 4          NaN        NaN          NaN         NaN       NaN          NaN
#
#   loc_santiago loc_talagante loc_talca loc_talcahuano loc_taltal loc_tarapaca  \
# 0          NaN           NaN       NaN            NaN        NaN          NaN
# 1          NaN           NaN       NaN            NaN        NaN          NaN
# 2          NaN           NaN       NaN            NaN        NaN          NaN
# 3          NaN           NaN       NaN            NaN        NaN          NaN
# 4          NaN           NaN       NaN            NaN        NaN          NaN
#
#   loc_temuco loc_tilcoco loc_tiltil loc_tocopilla loc_traiguen loc_valdivia  \
# 0        NaN         NaN        NaN           NaN          NaN          NaN
# 1        NaN         NaN        NaN           NaN          NaN          NaN
# 2        NaN         NaN        NaN           NaN          NaN          NaN
# 3        NaN         NaN        NaN           NaN          NaN          NaN
# 4        NaN         NaN        NaN           NaN          NaN          NaN
#
#   loc_vallenar loc_valparaiso loc_villarrica loc_vilos loc_vitacura loc_yumbel
# 0          NaN            NaN            NaN       NaN          NaN        NaN
# 1          NaN            NaN            NaN       NaN          NaN        NaN
# 2          NaN            NaN            NaN       NaN          NaN        NaN
# 3          NaN            NaN            NaN       NaN          NaN        NaN
# 4          NaN            NaN            NaN       NaN          NaN        NaN

# %%
bio_city_unigram.head()
# Out:
#                     id      conversation_id   author_id  bio_any_unigram_city  \
# 0  1513295387230019585  1512966960723595268   119939347                 False
# 1  1513152998792327168  1512870302224723973  2209329607                 False
# 2  1512902523190882308  1512240874842832898  2209329607                 False
# 3  1512595129630171136  1512595129630171136    66169172                 False
# 4  1512593335223005193  1512593335223005193    66169172                 False
#
#   bio_ancud bio_andacollo bio_angol bio_antofagasta bio_araucania bio_arauco  \
# 0       NaN           NaN       NaN             NaN           NaN        NaN
# 1       NaN           NaN       NaN             NaN           NaN        NaN
# 2       NaN           NaN       NaN             NaN           NaN        NaN
# 3       NaN           NaN       NaN             NaN           NaN        NaN
# 4       NaN           NaN       NaN             NaN           NaN        NaN
#
#   bio_arica bio_atacama bio_aysen bio_barnechea bio_biobio bio_buin  \
# 0       NaN         NaN       NaN           NaN        NaN      NaN
# 1       NaN         NaN       NaN           NaN        NaN      NaN
# 2       NaN         NaN       NaN           NaN        NaN      NaN
# 3       NaN         NaN       NaN           NaN        NaN      NaN
# 4       NaN         NaN       NaN           NaN        NaN      NaN
#
#   bio_calama bio_calbuco bio_calera bio_canete bio_carahue bio_catemu  \
# 0        NaN         NaN        NaN        NaN         NaN        NaN
# 1        NaN         NaN        NaN        NaN         NaN        NaN
# 2        NaN         NaN        NaN        NaN         NaN        NaN
# 3        NaN         NaN        NaN        NaN         NaN        NaN
# 4        NaN         NaN        NaN        NaN         NaN        NaN
#
#   bio_cauquenes bio_cerrillos bio_chanaral bio_chiguayante bio_chillan  \
# 0           NaN           NaN          NaN             NaN         NaN
# 1           NaN           NaN          NaN             NaN         NaN
# 2           NaN           NaN          NaN             NaN         NaN
# 3           NaN           NaN          NaN             NaN         NaN
# 4           NaN           NaN          NaN             NaN         NaN
#
#   bio_chimbarongo bio_chuquicamata bio_codegua bio_coelemu bio_coihueco  \
# 0             NaN              NaN         NaN         NaN          NaN
# 1             NaN              NaN         NaN         NaN          NaN
# 2             NaN              NaN         NaN         NaN          NaN
# 3             NaN              NaN         NaN         NaN          NaN
# 4             NaN              NaN         NaN         NaN          NaN
#
#   bio_collipulli bio_combarbala bio_conchali bio_concon bio_copiapo  \
# 0            NaN            NaN          NaN        NaN         NaN
# 1            NaN            NaN          NaN        NaN         NaN
# 2            NaN            NaN          NaN        NaN         NaN
# 3            NaN            NaN          NaN        NaN         NaN
# 4            NaN            NaN          NaN        NaN         NaN
#
#   bio_coquimbo bio_coyhaique bio_cunco bio_curacautin bio_curacavi  \
# 0          NaN           NaN       NaN            NaN          NaN
# 1          NaN           NaN       NaN            NaN          NaN
# 2          NaN           NaN       NaN            NaN          NaN
# 3          NaN           NaN       NaN            NaN          NaN
# 4          NaN           NaN       NaN            NaN          NaN
#
#   bio_curanilahue bio_curico bio_donihue bio_frutillar bio_futrono  \
# 0             NaN        NaN         NaN           NaN         NaN
# 1             NaN        NaN         NaN           NaN         NaN
# 2             NaN        NaN         NaN           NaN         NaN
# 3             NaN        NaN         NaN           NaN         NaN
# 4             NaN        NaN         NaN           NaN         NaN
#
#   bio_graneros bio_gultro bio_hijuelas bio_hualane bio_hualpen bio_hualqui  \
# 0          NaN        NaN          NaN         NaN         NaN         NaN
# 1          NaN        NaN          NaN         NaN         NaN         NaN
# 2          NaN        NaN          NaN         NaN         NaN         NaN
# 3          NaN        NaN          NaN         NaN         NaN         NaN
# 4          NaN        NaN          NaN         NaN         NaN         NaN
#
#   bio_huasco bio_huechuraba bio_huepil bio_illapel bio_iquique bio_lanco  \
# 0        NaN            NaN        NaN         NaN         NaN       NaN
# 1        NaN            NaN        NaN         NaN         NaN       NaN
# 2        NaN            NaN        NaN         NaN         NaN       NaN
# 3        NaN            NaN        NaN         NaN         NaN       NaN
# 4        NaN            NaN        NaN         NaN         NaN       NaN
#
#   bio_lebu bio_ligua bio_limache bio_llanquihue bio_llay-llay bio_loncoche  \
# 0      NaN       NaN         NaN            NaN           NaN          NaN
# 1      NaN       NaN         NaN            NaN           NaN          NaN
# 2      NaN       NaN         NaN            NaN           NaN          NaN
# 3      NaN       NaN         NaN            NaN           NaN          NaN
# 4      NaN       NaN         NaN            NaN           NaN          NaN
#
#   bio_longavi bio_machali bio_macul bio_maipo bio_maipu bio_mariquina  \
# 0         NaN         NaN       NaN       NaN       NaN           NaN
# 1         NaN         NaN       NaN       NaN       NaN           NaN
# 2         NaN         NaN       NaN       NaN       NaN           NaN
# 3         NaN         NaN       NaN       NaN       NaN           NaN
# 4         NaN         NaN       NaN       NaN       NaN           NaN
#
#   bio_maule bio_melipilla bio_muermos bio_mulchen bio_nancagua bio_nunoa  \
# 0       NaN           NaN         NaN         NaN          NaN       NaN
# 1       NaN           NaN         NaN         NaN          NaN       NaN
# 2       NaN           NaN         NaN         NaN          NaN       NaN
# 3       NaN           NaN         NaN         NaN          NaN       NaN
# 4       NaN           NaN         NaN         NaN          NaN       NaN
#
#   bio_o'higgins bio_olmue bio_ovalle bio_paillaco bio_paine bio_panguipulli  \
# 0           NaN       NaN        NaN          NaN       NaN             NaN
# 1           NaN       NaN        NaN          NaN       NaN             NaN
# 2           NaN       NaN        NaN          NaN       NaN             NaN
# 3           NaN       NaN        NaN          NaN       NaN             NaN
# 4           NaN       NaN        NaN          NaN       NaN             NaN
#
#   bio_parinacota bio_penalolen bio_pichilemu bio_pintana bio_pirque  \
# 0            NaN           NaN           NaN         NaN        NaN
# 1            NaN           NaN           NaN         NaN        NaN
# 2            NaN           NaN           NaN         NaN        NaN
# 3            NaN           NaN           NaN         NaN        NaN
# 4            NaN           NaN           NaN         NaN        NaN
#
#   bio_pitrufquen bio_placilla bio_pucon bio_pudahuel bio_puren bio_purranque  \
# 0            NaN          NaN       NaN          NaN       NaN           NaN
# 1            NaN          NaN       NaN          NaN       NaN           NaN
# 2            NaN          NaN       NaN          NaN       NaN           NaN
# 3            NaN          NaN       NaN          NaN       NaN           NaN
# 4            NaN          NaN       NaN          NaN       NaN           NaN
#
#   bio_putaendo bio_quellon bio_quilicura bio_quillon bio_quillota bio_quilpue  \
# 0          NaN         NaN           NaN         NaN          NaN         NaN
# 1          NaN         NaN           NaN         NaN          NaN         NaN
# 2          NaN         NaN           NaN         NaN          NaN         NaN
# 3          NaN         NaN           NaN         NaN          NaN         NaN
# 4          NaN         NaN           NaN         NaN          NaN         NaN
#
#   bio_quirihue bio_quisco bio_rancagua bio_renaico bio_renca bio_requinoa  \
# 0          NaN        NaN          NaN         NaN       NaN          NaN
# 1          NaN        NaN          NaN         NaN       NaN          NaN
# 2          NaN        NaN          NaN         NaN       NaN          NaN
# 3          NaN        NaN          NaN         NaN       NaN          NaN
# 4          NaN        NaN          NaN         NaN       NaN          NaN
#
#   bio_santiago bio_talagante bio_talca bio_talcahuano bio_taltal bio_tarapaca  \
# 0          NaN           NaN       NaN            NaN        NaN          NaN
# 1          NaN           NaN       NaN            NaN        NaN          NaN
# 2          NaN           NaN       NaN            NaN        NaN          NaN
# 3          NaN           NaN       NaN            NaN        NaN          NaN
# 4          NaN           NaN       NaN            NaN        NaN          NaN
#
#   bio_temuco bio_tilcoco bio_tiltil bio_tocopilla bio_traiguen bio_valdivia  \
# 0        NaN         NaN        NaN           NaN          NaN          NaN
# 1        NaN         NaN        NaN           NaN          NaN          NaN
# 2        NaN         NaN        NaN           NaN          NaN          NaN
# 3        NaN         NaN        NaN           NaN          NaN          NaN
# 4        NaN         NaN        NaN           NaN          NaN          NaN
#
#   bio_vallenar bio_valparaiso bio_villarrica bio_vilos bio_vitacura bio_yumbel
# 0          NaN            NaN            NaN       NaN          NaN        NaN
# 1          NaN            NaN            NaN       NaN          NaN        NaN
# 2          NaN            NaN            NaN       NaN          NaN        NaN
# 3          NaN            NaN            NaN       NaN          NaN        NaN
# 4          NaN            NaN            NaN       NaN          NaN        NaN

# %% [markdown]
# # 2. Merge Auxiliary Datasets

# %% [markdown]
# ## 2.0 Load Data, Set Lists

# %%
# Reload original twarc-file (making sure is raw)
start_df = pd.read_csv(path + sep + twarc_data, index_col = 0)

# Select cols
start_df_cols = ['id', 'conversation_id', 'author.username', 'author.description', 'author.location']
start_df = start_df[start_df_cols]
# Out:
# /var/folders/38/pqdkmnzn27z4y7tybr0ccrnc0000gn/T/ipykernel_65131/77210026.py:2: DtypeWarning: Columns (22,23,25,33,35,36,37,43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   start_df = pd.read_csv(path + sep + twarc_data, index_col = 0)

# %%
loc_df_list = [loc_emoji_chile_flag, loc_regex_chile, loc_regex_othercountry, loc_city_ngram, loc_city_unigram]
bio_df_list = [bio_emoji_chile_flag, bio_regex_chile, bio_regex_othercountry, bio_city_ngram, bio_city_unigram]

# %% [markdown]
# ## 2.1 Merge `loc` Auxiliary Datasets

# %%
start = datetime.now() #Start timer

# Merge auxiliary datasets:
for i in range(len(loc_df_list)):
    if i == 0:
        # Set dataframes to merge
        df1 = start_df; df2 = loc_df_list[i]
        
        # Select unique cols for dfs + 'id'
        cols_to_use = df2.columns.difference(df1.columns).to_list(); cols_to_use = ['id'] + cols_to_use
        
        # Merge
        loc_merged_df = df1.merge(df2[cols_to_use], on = 'id', validate = '1:1')
        
    else:
        # Set dataframes to merge
        df1 = loc_merged_df; df2 = loc_df_list[i]
        
        # Select unique cols for dfs + 'id'
        cols_to_use = df2.columns.difference(df1.columns).to_list(); cols_to_use = ['id'] + cols_to_use
        
        # Merge
        loc_merged_df = df1.merge(df2[cols_to_use], on = 'id', validate = '1:1')

        
###################################################################################
# Process resulting df
# Demojize author.location
for col in cols_list_loop:
    loc_merged_df[col] = loc_merged_df[col].astype("string").fillna("0")
    loc_merged_df[col] = loc_merged_df[col].apply(emoji.demojize)
    loc_merged_df[col] = loc_merged_df[col].replace('0', np.nan)

# Replace all new columns with False if NaN
my_cols = loc_merged_df.columns.to_list()
my_cols = my_cols[5:]

for col in my_cols:
    loc_merged_df[col] = loc_merged_df[col].replace(np.nan, False)
    

###################################################################################
#########        REORDER COLS              #########
# Reorder cols
# List of old cols
old_cols = loc_merged_df.columns.to_list()

# Ordered list og start cols
start_cols = start_df_cols + ['loc_chile_emoji', 'loc_contains_chile', 'loc_any_other_country', 
                              'loc_any_ngram_city', 'loc_any_unigram_city']

# Remove start cols from old list
for k in start_cols:
    old_cols.remove(k)

# New order
new_cols = start_cols + old_cols

# Reorder df
loc_merged_df = loc_merged_df[new_cols]

#########        MAKE RESITRCTIONS COL              #########
# Make one column to restrict on
restrict_cols = start_cols[5:]
restrict_cols.remove('loc_any_other_country')
loc_good_col = loc_merged_df[restrict_cols].any(axis = 1)

# Add restriction columns to merged_df
col_new_name = 'loc_good_col'
loc_to_restrict = pd.concat([loc_merged_df, loc_good_col], axis = 1)

# Rename, reorder, save
loc_to_restrict = loc_to_restrict.rename(columns = {0:col_new_name})
_ = loc_to_restrict.columns.to_list()
new_list = _[:5] + [col_new_name] + _[5:-1]
loc_to_restrict = loc_to_restrict[new_list]

    
print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Runtime: 0:10:06.475736

# %%
# Restrict: Keep only if either contains: 1) chile emoji, 2) 'chile', 3) n-gram chilean city, 4) unigram chilean city
df_loc_restrict = loc_to_restrict[loc_to_restrict.loc_good_col == True]

# %% [markdown]
# ## 2.2 Merge `bio` Auxiliary Datasets

# %%
start = datetime.now() #Start timer

# Merge auxiliary datasets:
for i in range(len(bio_df_list)):
    if i == 0:
        # Set dataframes to merge
        df1 = start_df; df2 = bio_df_list[i]
        
        # Select unique cols for dfs + 'id'
        cols_to_use = df2.columns.difference(df1.columns).to_list(); cols_to_use = ['id'] + cols_to_use
        
        # Merge
        bio_merged_df = df1.merge(df2[cols_to_use], on = 'id', validate = '1:1')
        
    else:
        # Set dataframes to merge
        df1 = bio_merged_df; df2 = bio_df_list[i]
        
        # Select unique cols for dfs + 'id'
        cols_to_use = df2.columns.difference(df1.columns).to_list(); cols_to_use = ['id'] + cols_to_use
        
        # Merge
        bio_merged_df = df1.merge(df2[cols_to_use], on = 'id', validate = '1:1')

        
###################################################################################
# Process resulting df
# Demojize author.location
for col in cols_list_loop:
    bio_merged_df[col] = bio_merged_df[col].astype("string").fillna("0")
    bio_merged_df[col] = bio_merged_df[col].apply(emoji.demojize)
    bio_merged_df[col] = bio_merged_df[col].replace("0", np.nan)

# Replace all new columns with False if NaN
my_cols = bio_merged_df.columns.to_list()
my_cols = my_cols[5:]

for col in my_cols:
    bio_merged_df[col] = bio_merged_df[col].replace(np.nan, False)
    

###################################################################################
#########        REORDER COLS              #########
# Reorder cols
# List of old cols
old_cols = bio_merged_df.columns.to_list()

# Ordered list og start cols
start_cols = start_df_cols + ['bio_chile_emoji', 'bio_contains_chile', 'bio_any_other_country', 
                              'bio_any_ngram_city', 'bio_any_unigram_city']

# Remove start cols from old list
for k in start_cols:
    old_cols.remove(k)

# New order
new_cols = start_cols + old_cols

# Reorder df
bio_merged_df = bio_merged_df[new_cols]

#########        MAKE RESITRCTIONS COL              #########
# Make one column to restrict on
restrict_cols = start_cols[5:]
restrict_cols.remove('bio_any_other_country')
bio_good_col = bio_merged_df[restrict_cols].any(axis = 1)

# Add restriction columns to merged_df
col_new_name = 'bio_good_col'
bio_to_restrict = pd.concat([bio_merged_df, bio_good_col], axis = 1)

# Rename, reorder, save
bio_to_restrict = bio_to_restrict.rename(columns = {0:col_new_name})
_ = bio_to_restrict.columns.to_list()
new_list = _[:5] + [col_new_name] + _[5:-1]
bio_to_restrict = bio_to_restrict[new_list]

    
print('Runtime:', datetime.now() - start) #Print runtime
# Out:
# Runtime: 0:09:36.076267

# %%
# Restrict: Keep only if either contains: 1) chile emoji, 2) 'chile', 3) n-gram chilean city, 4) unigram chilean city
df_bio_restrict = bio_to_restrict[bio_to_restrict.bio_good_col == True]

# %% [markdown]
# # 3. Final Geo-Restricted Dataset

# %%
# Remove non-restriction cols for readability
loc_cols = df_loc_restrict.columns.to_list()
bio_cols = df_bio_restrict.columns.to_list()

# List of new cols order
new_cols = ['id', 'conversation_id', 'author.username', 'author.description_x', 'author.description_y',
            'author.location_x', 'author.location_y', 'loc_good_col', 'bio_good_col'] 
new_cols = new_cols + loc_cols[6:11] + bio_cols[6:11]

# %%
# Merge both datasets
df_loc_bio_merge = df_loc_restrict.merge(df_bio_restrict, 
                                         how = 'outer',
                                         on = ['id', 'conversation_id', 'author.username'], 
                                         validate = '1:1')

# Apply new columns list
df_loc_bio_merge = df_loc_bio_merge[new_cols]

# Fix if loc or bio is null
df_loc_bio_merge['author.description_x'] = custom.fix_na_loc_bio(df1 = df_loc_bio_merge['author.description_x'],
                                                          df2 = df_loc_bio_merge['author.description_y'])
df_loc_bio_merge['author.description_y'] = custom.fix_na_loc_bio(df1 = df_loc_bio_merge['author.description_y'],
                                                          df2 = df_loc_bio_merge['author.description_x'])
df_loc_bio_merge['author.location_x'] = custom.fix_na_loc_bio(df1 = df_loc_bio_merge['author.location_x'],
                                                       df2 = df_loc_bio_merge['author.location_y'])
df_loc_bio_merge['author.location_x'] = custom.fix_na_loc_bio(df1 = df_loc_bio_merge['author.location_x'],
                                                       df2 = df_loc_bio_merge['author.location_x'])

# Drop "_y"-cols
df_loc_bio_merge = df_loc_bio_merge.drop(['author.description_y', 'author.location_y'], axis = 1)

# Rename column
df_loc_bio_merge = df_loc_bio_merge.rename(columns={'author.description_x':'author.description',
                                                   'author.location_x':'author.location'})

# Replace NaN to False in new columns
cols_loc_bio_merge = df_loc_bio_merge.columns.to_list()
cols_loc_bio_merge = cols_loc_bio_merge[5:]
for col in cols_loc_bio_merge:
    df_loc_bio_merge[col] = df_loc_bio_merge[col].fillna(False)

# %%
print("Proportion matched from original twarc-data:", "{:.2f}".format(len(df_loc_bio_merge)/len(start_df)*100), "%")
# Out:
# Proportion matched from original twarc-data: 63.94 %

# %%
df_loc_bio_merge.head(30)
# Out:
#                      id      conversation_id            author_id  \
# 0   1513295387230019585  1512966960723595268            119939347
# 1   1508093581508034569  1508093581508034569  1498451030014582787
# 2   1507517350899175428  1507148876775522318  1498451030014582787
# 3   1507024573354631168  1507024573354631168  1498451030014582787
# 4   1505958342153293826  1505892865741840392  1141471245185273868
# 5   1504917213576241153  1504848571685916675            263172782
# 6   1504591307913658374  1504591307913658374  1498451030014582787
# 7   1501590148886188033  1501590148886188033             31210711
# 8   1499550613171933184  1499548491055468547            263172782
# 9   1498698038314823681  1498698038314823681  1498451030014582787
# 10  1496889878008586242  1496889878008586242             70320557
# 11  1496451685434155011  1495956067347763202            851796446
# 12  1496451174618312704  1496232599093538819            851796446
# 13  1496450972612243458  1496216512587251715            851796446
# 14  1495493522790752258  1495177843885494275            851796446
# 15  1494401889202540552  1494401889202540552             31210711
# 16  1494396798043099137  1494312272440995843             31210711
# 17  1493962511342735362  1493962511342735362            367133504
# 18  1493549138369150980  1492560290818498564            134833604
# 19  1492621671718526976  1492341028803596293            851796446
# 20  1492567591776251906  1492567591776251906  1429503795910922240
# 21  1492518534110449666  1492507576726175747             31210711
# 22  1492483927151300618  1492171306573328389            526961553
# 23  1492480072518750208  1492291212417507331           1022708084
# 24  1492179344403226624  1492179344403226624             31509538
# 25  1492127558950817794  1492127558950817794            367133504
# 26  1491383453983850500  1491056273101496329  1141471245185273868
# 27  1488851027260366848  1488851027260366848           1022708084
# 28  1488836508127694851  1488836508127694851            851796446
# 29  1488669206191095808  1488529224751357952  1141471245185273868
#
#                                    author.description  \
# 0                                                 NaN
# 1                         Humano antes que todo... :)
# 2                         Humano antes que todo... :)
# 3                         Humano antes que todo... :)
# 4                    Paz en el mundo \n\n:dove::dove:
# 5   Vocero Comunidad Diaguita Autónoma. Médico Psi...
# 6                         Humano antes que todo... :)
# 7                                              RH 0 -
# 8   Vocero Comunidad Diaguita Autónoma. Médico Psi...
# 9                         Humano antes que todo... :)
# 10  Médico Cirujano :woman_health_worker_light_ski...
# 11  Los grandes cambios se logran con la razón y c...
# 12  Los grandes cambios se logran con la razón y c...
# 13  Los grandes cambios se logran con la razón y c...
# 14  Los grandes cambios se logran con la razón y c...
# 15                                             RH 0 -
# 16                                             RH 0 -
# 17  en este año perdí lo más amado a mi madre,mi a...
# 18                                                NaN
# 19  Los grandes cambios se logran con la razón y c...
# 20  Médico Cirujano, Máster en Salud Pública\nCasa...
# 21                                             RH 0 -
# 22                                                NaN
# 23                          :books::recycling_symbol:
# 24  :baby:Hijo/:men_holding_hands:Hermano/:person_...
# 25  en este año perdí lo más amado a mi madre,mi a...
# 26                   Paz en el mundo \n\n:dove::dove:
# 27                          :books::recycling_symbol:
# 28  Los grandes cambios se logran con la razón y c...
# 29                   Paz en el mundo \n\n:dove::dove:
#
#             author.location  loc_good_col  bio_good_col  loc_chile_emoji  \
# 0                     Chile          True         False            False
# 1            Iquique, Chile          True         False            False
# 2            Iquique, Chile          True         False            False
# 3            Iquique, Chile          True         False            False
# 4         Valparaíso, Chile          True         False            False
# 5                     Chile          True          True            False
# 6            Iquique, Chile          True         False            False
# 7   Entre Chile y Venezuela          True         False            False
# 8                     Chile          True          True            False
# 9            Iquique, Chile          True         False            False
# 10          Santiago, Chile          True         False            False
# 11          Santiago, Chile          True         False            False
# 12          Santiago, Chile          True         False            False
# 13          Santiago, Chile          True         False            False
# 14          Santiago, Chile          True         False            False
# 15  Entre Chile y Venezuela          True         False            False
# 16  Entre Chile y Venezuela          True         False            False
# 17          Santiago, Chile          True         False            False
# 18          Santiago, Chile          True         False            False
# 19          Santiago, Chile          True         False            False
# 20             Arica, Chile          True          True            False
# 21  Entre Chile y Venezuela          True         False            False
# 22          Vitacura, Chile          True         False            False
# 23          Santiago, Chile          True         False            False
# 24       Antofagasta, Chile          True          True            False
# 25          Santiago, Chile          True         False            False
# 26        Valparaíso, Chile          True         False            False
# 27          Santiago, Chile          True         False            False
# 28          Santiago, Chile          True         False            False
# 29        Valparaíso, Chile          True         False            False
#
#     loc_contains_chile  loc_any_other_country  loc_any_ngram_city  \
# 0                 True                   True               False
# 1                 True                   True                True
# 2                 True                   True                True
# 3                 True                   True                True
# 4                 True                   True                True
# 5                 True                   True               False
# 6                 True                   True                True
# 7                 True                   True               False
# 8                 True                   True               False
# 9                 True                   True                True
# 10                True                   True                True
# 11                True                   True                True
# 12                True                   True                True
# 13                True                   True                True
# 14                True                   True                True
# 15                True                   True               False
# 16                True                   True               False
# 17                True                   True                True
# 18                True                   True                True
# 19                True                   True                True
# 20                True                   True                True
# 21                True                   True               False
# 22                True                   True                True
# 23                True                   True                True
# 24                True                   True                True
# 25                True                   True                True
# 26                True                   True                True
# 27                True                   True                True
# 28                True                   True                True
# 29                True                   True                True
#
#     loc_any_unigram_city  bio_chile_emoji  bio_contains_chile  \
# 0                  False            False               False
# 1                   True            False               False
# 2                   True            False               False
# 3                   True            False               False
# 4                   True            False               False
# 5                  False            False                True
# 6                   True            False               False
# 7                  False            False               False
# 8                  False            False                True
# 9                   True            False               False
# 10                  True            False               False
# 11                  True            False               False
# 12                  True            False               False
# 13                  True            False               False
# 14                  True            False               False
# 15                 False            False               False
# 16                 False            False               False
# 17                  True            False               False
# 18                  True            False               False
# 19                  True            False               False
# 20                  True             True                True
# 21                 False            False               False
# 22                  True            False               False
# 23                  True            False               False
# 24                  True             True                True
# 25                  True            False               False
# 26                  True            False               False
# 27                  True            False               False
# 28                  True            False               False
# 29                  True            False               False
#
#     bio_any_other_country  bio_any_ngram_city  bio_any_unigram_city
# 0                   False               False                 False
# 1                   False               False                 False
# 2                   False               False                 False
# 3                   False               False                 False
# 4                   False               False                 False
# 5                    True               False                 False
# 6                   False               False                 False
# 7                   False               False                 False
# 8                    True               False                 False
# 9                   False               False                 False
# 10                  False               False                 False
# 11                  False               False                 False
# 12                  False               False                 False
# 13                  False               False                 False
# 14                  False               False                 False
# 15                  False               False                 False
# 16                  False               False                 False
# 17                  False               False                 False
# 18                  False               False                 False
# 19                  False               False                 False
# 20                   True                True                  True
# 21                  False               False                 False
# 22                  False               False                 False
# 23                  False               False                 False
# 24                   True               False                 False
# 25                  False               False                 False
# 26                  False               False                 False
# 27                  False               False                 False
# 28                  False               False                 False
# 29                  False               False                 False

# %% [markdown]
# # 4. Inspect

# %% [markdown]
# ## 4.1 Random Samples

# %%
df = df_loc_bio_merge
n_tweets = 10

for i in range(0, n_tweets):
    indexes = list(df.index) 
    a = random.choice(indexes)
    print('ID:', df['id'][a])
    print('Location:', df['author.location'][a])
    print('Description:', df['author.description'][a])
    print("")
    indexes.remove(a)
# Out:
# ID: 1488611063025188865
# Location: Chile
# Description: Diseñador Industrial | Artista 3D&CGI | Fotógrafo Aficionado. :camera:  ||  Industrial Designer | 3D&CGI Artist | Amateur Photographer. :camera:
#
# ID: 1386797631372939268
# Location: Santiago,Chile
# Description: ¡Súmate al camino de la ERRADICACIÓN de la situación de calle y la recuperación de DERECHOS! Teléfono: +56 2 27774575. E-mail: info@gentedelacalle.cl
#
# ID: 1486659648618995712
# Location: nan
# Description: El innombrable mechero, oportunista y basura política. Nunca será mi presidente. Mi Chile lindo! nunca quiero perderte
#
# ID: 1486096694496223232
# Location: Chile
# Description: Curacautin, Araucania, Chile
#
# ID: 1495745317970587659
# Location: Aculeo. Santiago de Chile.
# Description: Ingeniero Civil Matemático. \nDoctor en Ingeniería de Minas.\nPresidente Federación de Biathlón de Chile
#
# ID: 1440846447084118027
# Location: Chile
# Description: "La educación te hace libre, la ignorancia esclavo."
#
# ID: 1456370141088804865
# Location: Santiago de Chile
# Description: Ciudadana del mundo.:globe_showing_Asia-Australia::milky_way:\nEres lo que haces, no lo que dices que vas hacer .
#
# ID: 1485965653949358083
# Location: Valparaíso, Chile.
# Description: Porteño y Periodista :railway_car::movie_camera:
#
# ID: 1443680916476473345
# Location: Santiago, Chile
# Description: No mas #SERVICIOJESUITAMIGRANTE en Chile #NomasONU . Singapurista a la chilena, chilenials chilenialista. SÍGUEME Y TE SIGO .
#
# ID: 1491966055060701187
# Location: nan
# Description: O la tiranía marxista o la libertad.:Statue_of_Liberty:\nRepublicana:Chile:Anticomunista\nResistencia Patriota :Chile:\nRechazo:Chile:22%/44%\n                  Kast por siempre:victory_hand::growing_heart::Chile:

# %% [markdown]
# ## 4.2 Visuals

# %% [markdown]
# Bar plot with top 20 author locations:

# %%
# Set data
df = df_loc_bio_merge

# General settings
sns.set_theme(style = "whitegrid")
plt.figure(figsize = (20, 10))

# Make figure
ax = sns.barplot(x = df['author.location'].value_counts().index[:20], 
                 y = df['author.location'].value_counts()[:20])
ax = ax.set_xticklabels(ax.get_xticklabels(), rotation = 90, size = 14)

# %% [markdown]
# Wordcloud for author descriptions

# %%
# For wordcloud all 'author.description' rows should be made into one long string 
textjoin = custom.wordcloud_preproz(df = df, col = 'author.description', hash_rm = True)
#print(textjoin[0:1000])

# Make wordcloud
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(textjoin)

# Display the generated image:
plt.figure(figsize = (20, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off"); plt.show()

# %% [markdown]
# # 5. Export

# %%
# Check path for exported .csv
print(out_file)
# Out:
# /Users/mathiasschindler/Library/Mobile Documents/com~apple~CloudDocs/BSE/_T3--Thesis/data_out/22-06-03-all_tweets_cleaned_filter_chileans.csv

# %%
# Export .csv-file
df_loc_bio_merge.to_csv(out_file)

# %%
df_loc_bio_merge.shape
# Out:
# (573999, 17)

# %%
#Print runtime
print('Runtime for entire notebook:', datetime.now() - notebook_start)
# Out:
# Runtime for entire notebook: 1:04:43.349335

# %%
df_loc_bio_merge
# Out:
#                          id      conversation_id            author_id  \
# 0       1513295387230019585  1512966960723595268            119939347
# 1       1508093581508034569  1508093581508034569  1498451030014582787
# 2       1507517350899175428  1507148876775522318  1498451030014582787
# 3       1507024573354631168  1507024573354631168  1498451030014582787
# 4       1505958342153293826  1505892865741840392  1141471245185273868
# ...                     ...                  ...                  ...
# 573994  1490787126224605188  1490787126224605188           2978090513
# 573995  1471140821915234304  1471139366202318853  1380557185776820226
# 573996  1446223288833806344  1446223288833806344           2978090513
# 573997  1417512212361527299  1417512212361527299           2978090513
# 573998  1359839906885943296  1359839906885943296            520689615
#
#                                        author.description  \
# 0                                                     NaN
# 1                             Humano antes que todo... :)
# 2                             Humano antes que todo... :)
# 3                             Humano antes que todo... :)
# 4                        Paz en el mundo \n\n:dove::dove:
# ...                                                   ...
# 573994  La Cámara Oficial Española de Comercio de Chil...
# 573995                         Chile :round_pushpin: / 22
# 573996  La Cámara Oficial Española de Comercio de Chil...
# 573997  La Cámara Oficial Española de Comercio de Chil...
# 573998  Arquitecto Urbanista, idealista e hincha de la...
#
#                        author.location  loc_good_col  bio_good_col  \
# 0                                Chile          True         False
# 1                       Iquique, Chile          True         False
# 2                       Iquique, Chile          True         False
# 3                       Iquique, Chile          True         False
# 4                    Valparaíso, Chile          True         False
# ...                                ...           ...           ...
# 573994  Carmen Sylva 2306, Providencia         False          True
# 573995                             NaN         False          True
# 573996  Carmen Sylva 2306, Providencia         False          True
# 573997  Carmen Sylva 2306, Providencia         False          True
# 573998                             NaN         False          True
#
#         loc_chile_emoji  loc_contains_chile  loc_any_other_country  \
# 0                 False                True                   True
# 1                 False                True                   True
# 2                 False                True                   True
# 3                 False                True                   True
# 4                 False                True                   True
# ...                 ...                 ...                    ...
# 573994            False               False                  False
# 573995            False               False                  False
# 573996            False               False                  False
# 573997            False               False                  False
# 573998            False               False                  False
#
#         loc_any_ngram_city  loc_any_unigram_city  bio_chile_emoji  \
# 0                    False                 False            False
# 1                     True                  True            False
# 2                     True                  True            False
# 3                     True                  True            False
# 4                     True                  True            False
# ...                    ...                   ...              ...
# 573994               False                 False            False
# 573995               False                 False            False
# 573996               False                 False            False
# 573997               False                 False            False
# 573998               False                 False            False
#
#         bio_contains_chile  bio_any_other_country  bio_any_ngram_city  \
# 0                    False                  False               False
# 1                    False                  False               False
# 2                    False                  False               False
# 3                    False                  False               False
# 4                    False                  False               False
# ...                    ...                    ...                 ...
# 573994                True                   True                True
# 573995                True                   True               False
# 573996                True                   True                True
# 573997                True                   True                True
# 573998                True                   True               False
#
#         bio_any_unigram_city
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 573994                  True
# 573995                 False
# 573996                  True
# 573997                  True
# 573998                 False
#
# [573999 rows x 17 columns]
